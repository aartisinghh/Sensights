# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
#load the data
df = pd.read_csv('sudo model 1.csv')
df.head()
# Out:
#    Unnamed: 0 Result  Target  PR_Interval  RR_Interval  RS_Interval
# 0           1      j       1     0.000000     0.000000  3699.119444
# 1           2      N       0     0.052778     0.108333     0.230556
# 2           3  (AFIB       1     0.077778     0.300000 -4136.461111
# 3           4      j       1     0.000000     0.000000  3924.050000
# 4           5   (AFL       1     0.061111     0.119444     0.244444

# %%
df = df.iloc[:, 2:]
df.head()
# Out:
#    Target  PR_Interval  RR_Interval  RS_Interval
# 0       1     0.000000     0.000000  3699.119444
# 1       0     0.052778     0.108333     0.230556
# 2       1     0.077778     0.300000 -4136.461111
# 3       1     0.000000     0.000000  3924.050000
# 4       1     0.061111     0.119444     0.244444

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
#le = LabelEncoder()
#le.fit(y)
#y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#define the model
model = Sequential()
model.add(Dense(4, activation='tanh', use_bias=True, input_shape=(3,)))
model.add(Dense(6, activation='tanh', use_bias=True))
model.add(Dense(6, activation='tanh', use_bias=True))
model.add(Dense(6, activation='tanh', use_bias=True))
model.add(Dense(6, activation='tanh', use_bias=True))

model.add(Dense(2, activation='softmax'))

# %%
#complie the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=100, batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 11/11 - 0s - loss: 0.8934 - accuracy: 0.2078 - 396ms/epoch - 36ms/step
# Epoch 2/100
# 11/11 - 0s - loss: 0.7372 - accuracy: 0.4544 - 18ms/epoch - 2ms/step
# Epoch 3/100
# 11/11 - 0s - loss: 0.6145 - accuracy: 0.8097 - 21ms/epoch - 2ms/step
# Epoch 4/100
# 11/11 - 0s - loss: 0.5209 - accuracy: 0.8427 - 20ms/epoch - 2ms/step
# Epoch 5/100
# 11/11 - 0s - loss: 0.4732 - accuracy: 0.8233 - 21ms/epoch - 2ms/step
# Epoch 6/100
# 11/11 - 0s - loss: 0.4473 - accuracy: 0.8233 - 18ms/epoch - 2ms/step
# Epoch 7/100
# 11/11 - 0s - loss: 0.4267 - accuracy: 0.8233 - 20ms/epoch - 2ms/step
# Epoch 8/100
# 11/11 - 0s - loss: 0.4128 - accuracy: 0.8233 - 21ms/epoch - 2ms/step
# Epoch 9/100
# 11/11 - 0s - loss: 0.4008 - accuracy: 0.8233 - 18ms/epoch - 2ms/step
# Epoch 10/100
# 11/11 - 0s - loss: 0.3921 - accuracy: 0.8233 - 20ms/epoch - 2ms/step
# Epoch 11/100
# 11/11 - 0s - loss: 0.3837 - accuracy: 0.8350 - 17ms/epoch - 2ms/step
# Epoch 12/100
# 11/11 - 0s - loss: 0.3781 - accuracy: 0.8563 - 23ms/epoch - 2ms/step
# Epoch 13/100
# 11/11 - 0s - loss: 0.3716 - accuracy: 0.8563 - 18ms/epoch - 2ms/step
# Epoch 14/100
# 11/11 - 0s - loss: 0.3672 - accuracy: 0.8680 - 21ms/epoch - 2ms/step
# Epoch 15/100
# 11/11 - 0s - loss: 0.3631 - accuracy: 0.8913 - 19ms/epoch - 2ms/step
# Epoch 16/100
# 11/11 - 0s - loss: 0.3598 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 17/100
# 11/11 - 0s - loss: 0.3576 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 18/100
# 11/11 - 0s - loss: 0.3555 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 19/100
# 11/11 - 0s - loss: 0.3541 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 20/100
# 11/11 - 0s - loss: 0.3528 - accuracy: 0.8913 - 22ms/epoch - 2ms/step
# Epoch 21/100
# 11/11 - 0s - loss: 0.3517 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 22/100
# 11/11 - 0s - loss: 0.3505 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 23/100
# 11/11 - 0s - loss: 0.3496 - accuracy: 0.8913 - 22ms/epoch - 2ms/step
# Epoch 24/100
# 11/11 - 0s - loss: 0.3488 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 25/100
# 11/11 - 0s - loss: 0.3478 - accuracy: 0.8913 - 23ms/epoch - 2ms/step
# Epoch 26/100
# 11/11 - 0s - loss: 0.3471 - accuracy: 0.8913 - 22ms/epoch - 2ms/step
# Epoch 27/100
# 11/11 - 0s - loss: 0.3462 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 28/100
# 11/11 - 0s - loss: 0.3456 - accuracy: 0.8913 - 19ms/epoch - 2ms/step
# Epoch 29/100
# 11/11 - 0s - loss: 0.3448 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 30/100
# 11/11 - 0s - loss: 0.3442 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 31/100
# 11/11 - 0s - loss: 0.3437 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 32/100
# 11/11 - 0s - loss: 0.3429 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 33/100
# 11/11 - 0s - loss: 0.3424 - accuracy: 0.8913 - 22ms/epoch - 2ms/step
# Epoch 34/100
# 11/11 - 0s - loss: 0.3419 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 35/100
# 11/11 - 0s - loss: 0.3412 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 36/100
# 11/11 - 0s - loss: 0.3408 - accuracy: 0.8913 - 19ms/epoch - 2ms/step
# Epoch 37/100
# 11/11 - 0s - loss: 0.3402 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 38/100
# 11/11 - 0s - loss: 0.3398 - accuracy: 0.8913 - 21ms/epoch - 2ms/step
# Epoch 39/100
# 11/11 - 0s - loss: 0.3390 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 40/100
# 11/11 - 0s - loss: 0.3386 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 41/100
# 11/11 - 0s - loss: 0.3380 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 42/100
# 11/11 - 0s - loss: 0.3376 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 43/100
# 11/11 - 0s - loss: 0.3372 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 44/100
# 11/11 - 0s - loss: 0.3366 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 45/100
# 11/11 - 0s - loss: 0.3362 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 46/100
# 11/11 - 0s - loss: 0.3358 - accuracy: 0.8913 - 19ms/epoch - 2ms/step
# Epoch 47/100
# 11/11 - 0s - loss: 0.3353 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 48/100
# 11/11 - 0s - loss: 0.3347 - accuracy: 0.8913 - 22ms/epoch - 2ms/step
# Epoch 49/100
# 11/11 - 0s - loss: 0.3345 - accuracy: 0.8913 - 14ms/epoch - 1ms/step
# Epoch 50/100
# 11/11 - 0s - loss: 0.3336 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 51/100
# 11/11 - 0s - loss: 0.3333 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 52/100
# 11/11 - 0s - loss: 0.3330 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 53/100
# 11/11 - 0s - loss: 0.3327 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 54/100
# 11/11 - 0s - loss: 0.3320 - accuracy: 0.8913 - 12ms/epoch - 1ms/step
# Epoch 55/100
# 11/11 - 0s - loss: 0.3317 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 56/100
# 11/11 - 0s - loss: 0.3313 - accuracy: 0.8913 - 20ms/epoch - 2ms/step
# Epoch 57/100
# 11/11 - 0s - loss: 0.3309 - accuracy: 0.8913 - 13ms/epoch - 1ms/step
# Epoch 58/100
# 11/11 - 0s - loss: 0.3305 - accuracy: 0.8913 - 13ms/epoch - 1ms/step
# Epoch 59/100
# 11/11 - 0s - loss: 0.3302 - accuracy: 0.8913 - 28ms/epoch - 3ms/step
# Epoch 60/100
# 11/11 - 0s - loss: 0.3298 - accuracy: 0.8913 - 13ms/epoch - 1ms/step
# Epoch 61/100
# 11/11 - 0s - loss: 0.3295 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 62/100
# 11/11 - 0s - loss: 0.3292 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 63/100
# 11/11 - 0s - loss: 0.3288 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 64/100
# 11/11 - 0s - loss: 0.3285 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 65/100
# 11/11 - 0s - loss: 0.3282 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 66/100
# 11/11 - 0s - loss: 0.3281 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 67/100
# 11/11 - 0s - loss: 0.3277 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 68/100
# 11/11 - 0s - loss: 0.3273 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 69/100
# 11/11 - 0s - loss: 0.3269 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 70/100
# 11/11 - 0s - loss: 0.3267 - accuracy: 0.8913 - 12ms/epoch - 1ms/step
# Epoch 71/100
# 11/11 - 0s - loss: 0.3266 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 72/100
# 11/11 - 0s - loss: 0.3262 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 73/100
# 11/11 - 0s - loss: 0.3260 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 74/100
# 11/11 - 0s - loss: 0.3259 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 75/100
# 11/11 - 0s - loss: 0.3256 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 76/100
# 11/11 - 0s - loss: 0.3254 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 77/100
# 11/11 - 0s - loss: 0.3256 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 78/100
# 11/11 - 0s - loss: 0.3251 - accuracy: 0.8913 - 13ms/epoch - 1ms/step
# Epoch 79/100
# 11/11 - 0s - loss: 0.3248 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 80/100
# 11/11 - 0s - loss: 0.3246 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 81/100
# 11/11 - 0s - loss: 0.3244 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 82/100
# 11/11 - 0s - loss: 0.3243 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 83/100
# 11/11 - 0s - loss: 0.3242 - accuracy: 0.8913 - 19ms/epoch - 2ms/step
# Epoch 84/100
# 11/11 - 0s - loss: 0.3240 - accuracy: 0.8913 - 18ms/epoch - 2ms/step
# Epoch 85/100
# 11/11 - 0s - loss: 0.3242 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 86/100
# 11/11 - 0s - loss: 0.3238 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 87/100
# 11/11 - 0s - loss: 0.3232 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 88/100
# 11/11 - 0s - loss: 0.3233 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 89/100
# 11/11 - 0s - loss: 0.3232 - accuracy: 0.8913 - 14ms/epoch - 1ms/step
# Epoch 90/100
# 11/11 - 0s - loss: 0.3232 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 91/100
# 11/11 - 0s - loss: 0.3231 - accuracy: 0.8913 - 14ms/epoch - 1ms/step
# Epoch 92/100
# 11/11 - 0s - loss: 0.3228 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 93/100
# 11/11 - 0s - loss: 0.3226 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 94/100
# 11/11 - 0s - loss: 0.3225 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 95/100
# 11/11 - 0s - loss: 0.3222 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 96/100
# 11/11 - 0s - loss: 0.3222 - accuracy: 0.8913 - 16ms/epoch - 1ms/step
# Epoch 97/100
# 11/11 - 0s - loss: 0.3222 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 98/100
# 11/11 - 0s - loss: 0.3218 - accuracy: 0.8913 - 15ms/epoch - 1ms/step
# Epoch 99/100
# 11/11 - 0s - loss: 0.3218 - accuracy: 0.8913 - 17ms/epoch - 2ms/step
# Epoch 100/100
# 11/11 - 0s - loss: 0.3216 - accuracy: 0.8913 - 16ms/epoch - 1ms/step

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
# Out:
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3168 - accuracy: 0.8913

# %%
# make a prediction
yhat = model.predict(X)
print(yhat)
# Out:
# [[0.05258626 0.94741374]
#  [0.17412809 0.8258719 ]
#  [0.         1.        ]
#  ...
#  [0.17136428 0.8286357 ]
#  [0.17235582 0.82764417]
#  [0.0551872  0.9448128 ]]
