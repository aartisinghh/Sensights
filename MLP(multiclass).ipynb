# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
#load the data
df = pd.read_csv('sudo model 1.csv')
df.head()
# Out:
#    Unnamed: 0 Result  Target  PR_Interval  RR_Interval  RS_Interval
# 0           1      j       1     0.000000     0.000000  3699.119444
# 1           2      N       0     0.052778     0.108333     0.230556
# 2           3  (AFIB       1     0.077778     0.300000 -4136.461111
# 3           4      j       1     0.000000     0.000000  3924.050000
# 4           5   (AFL       1     0.061111     0.119444     0.244444

# %%
df = df[["Result", "PR_Interval", "RR_Interval", "RS_Interval"]]
df.head()
# Out:
#   Result  PR_Interval  RR_Interval  RS_Interval
# 0      j     0.000000     0.000000  3699.119444
# 1      N     0.052778     0.108333     0.230556
# 2  (AFIB     0.077778     0.300000 -4136.461111
# 3      j     0.000000     0.000000  3924.050000
# 4   (AFL     0.061111     0.119444     0.244444

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#define the model
model = Sequential()
model.add(Dense(3, activation='relu', use_bias=True, input_shape=(3,)))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(5, activation='softmax'))

# %%
#complie the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=50000, batch_size=50, verbose=2)
# Out:
# Epoch 1/50000
# 11/11 - 0s - loss: 0.8398 - accuracy: 0.6485 - 31ms/epoch - 3ms/step
# Epoch 2/50000
# 11/11 - 0s - loss: 0.8359 - accuracy: 0.6524 - 24ms/epoch - 2ms/step
# Epoch 3/50000
# 11/11 - 0s - loss: 0.8344 - accuracy: 0.6563 - 17ms/epoch - 2ms/step
# Epoch 4/50000
# 11/11 - 0s - loss: 0.8406 - accuracy: 0.6524 - 24ms/epoch - 2ms/step
# Epoch 5/50000
# 11/11 - 0s - loss: 0.8343 - accuracy: 0.6563 - 28ms/epoch - 3ms/step
# Epoch 6/50000
# 11/11 - 0s - loss: 0.8311 - accuracy: 0.6583 - 26ms/epoch - 2ms/step
# Epoch 7/50000
# 11/11 - 0s - loss: 0.8321 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 8/50000
# 11/11 - 0s - loss: 0.8371 - accuracy: 0.6544 - 23ms/epoch - 2ms/step
# Epoch 9/50000
# 11/11 - 0s - loss: 0.8386 - accuracy: 0.6660 - 28ms/epoch - 3ms/step
# Epoch 10/50000
# 11/11 - 0s - loss: 0.8484 - accuracy: 0.6408 - 21ms/epoch - 2ms/step
# Epoch 11/50000
# 11/11 - 0s - loss: 0.8511 - accuracy: 0.6485 - 20ms/epoch - 2ms/step
# Epoch 12/50000
# 11/11 - 0s - loss: 0.8453 - accuracy: 0.6621 - 23ms/epoch - 2ms/step
# Epoch 13/50000
# 11/11 - 0s - loss: 0.8576 - accuracy: 0.6524 - 30ms/epoch - 3ms/step
# Epoch 14/50000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6485 - 26ms/epoch - 2ms/step
# Epoch 15/50000
# 11/11 - 0s - loss: 0.8693 - accuracy: 0.6408 - 24ms/epoch - 2ms/step
# Epoch 16/50000
# 11/11 - 0s - loss: 1.0093 - accuracy: 0.6427 - 21ms/epoch - 2ms/step
# Epoch 17/50000
# 11/11 - 0s - loss: 0.9079 - accuracy: 0.6388 - 23ms/epoch - 2ms/step
# Epoch 18/50000
# 11/11 - 0s - loss: 0.8703 - accuracy: 0.6505 - 20ms/epoch - 2ms/step
# Epoch 19/50000
# 11/11 - 0s - loss: 0.9145 - accuracy: 0.6291 - 26ms/epoch - 2ms/step
# Epoch 20/50000
# 11/11 - 0s - loss: 0.9648 - accuracy: 0.6272 - 22ms/epoch - 2ms/step
# Epoch 21/50000
# 11/11 - 0s - loss: 0.8913 - accuracy: 0.6369 - 20ms/epoch - 2ms/step
# Epoch 22/50000
# 11/11 - 0s - loss: 0.8736 - accuracy: 0.6466 - 20ms/epoch - 2ms/step
# Epoch 23/50000
# 11/11 - 0s - loss: 0.9428 - accuracy: 0.6252 - 20ms/epoch - 2ms/step
# Epoch 24/50000
# 11/11 - 0s - loss: 0.8646 - accuracy: 0.6466 - 17ms/epoch - 2ms/step
# Epoch 25/50000
# 11/11 - 0s - loss: 0.8635 - accuracy: 0.6388 - 21ms/epoch - 2ms/step
# Epoch 26/50000
# 11/11 - 0s - loss: 0.8657 - accuracy: 0.6485 - 22ms/epoch - 2ms/step
# Epoch 27/50000
# 11/11 - 0s - loss: 0.8602 - accuracy: 0.6408 - 20ms/epoch - 2ms/step
# Epoch 28/50000
# 11/11 - 0s - loss: 0.8344 - accuracy: 0.6602 - 26ms/epoch - 2ms/step
# Epoch 29/50000
# 11/11 - 0s - loss: 0.8401 - accuracy: 0.6621 - 20ms/epoch - 2ms/step
# Epoch 30/50000
# 11/11 - 0s - loss: 0.8375 - accuracy: 0.6602 - 23ms/epoch - 2ms/step
# Epoch 31/50000
# 11/11 - 0s - loss: 0.8347 - accuracy: 0.6621 - 19ms/epoch - 2ms/step
# Epoch 32/50000
# 11/11 - 0s - loss: 0.8385 - accuracy: 0.6466 - 22ms/epoch - 2ms/step
# Epoch 33/50000
# 11/11 - 0s - loss: 0.8393 - accuracy: 0.6602 - 25ms/epoch - 2ms/step
# Epoch 34/50000
# 11/11 - 0s - loss: 0.8504 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 35/50000
# 11/11 - 0s - loss: 0.8372 - accuracy: 0.6641 - 22ms/epoch - 2ms/step
# Epoch 36/50000
# 11/11 - 0s - loss: 0.8425 - accuracy: 0.6544 - 21ms/epoch - 2ms/step
# Epoch 37/50000
# 11/11 - 0s - loss: 0.8460 - accuracy: 0.6563 - 22ms/epoch - 2ms/step
# Epoch 38/50000
# 11/11 - 0s - loss: 0.8357 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 39/50000
# 11/11 - 0s - loss: 0.8410 - accuracy: 0.6524 - 20ms/epoch - 2ms/step
# Epoch 40/50000
# 11/11 - 0s - loss: 0.8324 - accuracy: 0.6602 - 23ms/epoch - 2ms/step
# Epoch 41/50000
# 11/11 - 0s - loss: 0.8408 - accuracy: 0.6621 - 20ms/epoch - 2ms/step
# Epoch 42/50000
# 11/11 - 0s - loss: 0.8356 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 43/50000
# 11/11 - 0s - loss: 0.8339 - accuracy: 0.6621 - 21ms/epoch - 2ms/step
# Epoch 44/50000
# 11/11 - 0s - loss: 0.8367 - accuracy: 0.6621 - 26ms/epoch - 2ms/step
# Epoch 45/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6544 - 23ms/epoch - 2ms/step
# Epoch 46/50000
# 11/11 - 0s - loss: 0.8392 - accuracy: 0.6641 - 24ms/epoch - 2ms/step
# Epoch 47/50000
# 11/11 - 0s - loss: 0.8333 - accuracy: 0.6621 - 21ms/epoch - 2ms/step
# Epoch 48/50000
# 11/11 - 0s - loss: 0.8412 - accuracy: 0.6583 - 23ms/epoch - 2ms/step
# Epoch 49/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6563 - 19ms/epoch - 2ms/step
# Epoch 50/50000
# 11/11 - 0s - loss: 0.8348 - accuracy: 0.6602 - 24ms/epoch - 2ms/step
# Epoch 51/50000
# 11/11 - 0s - loss: 0.8367 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 52/50000
# 11/11 - 0s - loss: 0.8307 - accuracy: 0.6641 - 25ms/epoch - 2ms/step
# Epoch 53/50000
# 11/11 - 0s - loss: 0.8310 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 54/50000
# 11/11 - 0s - loss: 0.8303 - accuracy: 0.6583 - 22ms/epoch - 2ms/step
# Epoch 55/50000
# 11/11 - 0s - loss: 0.8336 - accuracy: 0.6602 - 24ms/epoch - 2ms/step
# Epoch 56/50000
# 11/11 - 0s - loss: 0.8349 - accuracy: 0.6544 - 26ms/epoch - 2ms/step
# Epoch 57/50000
# 11/11 - 0s - loss: 0.8358 - accuracy: 0.6485 - 20ms/epoch - 2ms/step
# Epoch 58/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6505 - 18ms/epoch - 2ms/step
# Epoch 59/50000
# 11/11 - 0s - loss: 0.8503 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 60/50000
# 11/11 - 0s - loss: 0.8587 - accuracy: 0.6505 - 20ms/epoch - 2ms/step
# Epoch 61/50000
# 11/11 - 0s - loss: 0.8377 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 62/50000
# 11/11 - 0s - loss: 0.8459 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 63/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 64/50000
# 11/11 - 0s - loss: 0.8527 - accuracy: 0.6485 - 20ms/epoch - 2ms/step
# Epoch 65/50000
# 11/11 - 0s - loss: 0.8436 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 66/50000
# 11/11 - 0s - loss: 0.8383 - accuracy: 0.6641 - 18ms/epoch - 2ms/step
# Epoch 67/50000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6583 - 18ms/epoch - 2ms/step
# Epoch 68/50000
# 11/11 - 0s - loss: 0.8416 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 69/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 70/50000
# 11/11 - 0s - loss: 0.8564 - accuracy: 0.6505 - 18ms/epoch - 2ms/step
# Epoch 71/50000
# 11/11 - 0s - loss: 0.8376 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 72/50000
# 11/11 - 0s - loss: 0.8639 - accuracy: 0.6291 - 16ms/epoch - 1ms/step
# Epoch 73/50000
# 11/11 - 0s - loss: 0.8612 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 74/50000
# 11/11 - 0s - loss: 0.8609 - accuracy: 0.6427 - 18ms/epoch - 2ms/step
# Epoch 75/50000
# 11/11 - 0s - loss: 0.8427 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 76/50000
# 11/11 - 0s - loss: 0.8426 - accuracy: 0.6563 - 19ms/epoch - 2ms/step
# Epoch 77/50000
# 11/11 - 0s - loss: 0.8483 - accuracy: 0.6466 - 18ms/epoch - 2ms/step
# Epoch 78/50000
# 11/11 - 0s - loss: 0.8495 - accuracy: 0.6563 - 17ms/epoch - 2ms/step
# Epoch 79/50000
# 11/11 - 0s - loss: 0.8490 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 80/50000
# 11/11 - 0s - loss: 0.8467 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 81/50000
# 11/11 - 0s - loss: 0.8382 - accuracy: 0.6602 - 16ms/epoch - 1ms/step
# Epoch 82/50000
# 11/11 - 0s - loss: 0.8352 - accuracy: 0.6660 - 19ms/epoch - 2ms/step
# Epoch 83/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 84/50000
# 11/11 - 0s - loss: 0.8463 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 85/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6680 - 25ms/epoch - 2ms/step
# Epoch 86/50000
# 11/11 - 0s - loss: 0.8391 - accuracy: 0.6641 - 24ms/epoch - 2ms/step
# Epoch 87/50000
# 11/11 - 0s - loss: 0.8405 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 88/50000
# 11/11 - 0s - loss: 0.8298 - accuracy: 0.6583 - 18ms/epoch - 2ms/step
# Epoch 89/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 90/50000
# 11/11 - 0s - loss: 0.8459 - accuracy: 0.6602 - 21ms/epoch - 2ms/step
# Epoch 91/50000
# 11/11 - 0s - loss: 0.8393 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 92/50000
# 11/11 - 0s - loss: 0.8436 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 93/50000
# 11/11 - 0s - loss: 0.8558 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 94/50000
# 11/11 - 0s - loss: 0.8532 - accuracy: 0.6447 - 19ms/epoch - 2ms/step
# Epoch 95/50000
# 11/11 - 0s - loss: 0.8444 - accuracy: 0.6602 - 19ms/epoch - 2ms/step
# Epoch 96/50000
# 11/11 - 0s - loss: 0.8360 - accuracy: 0.6641 - 17ms/epoch - 2ms/step
# Epoch 97/50000
# 11/11 - 0s - loss: 0.8343 - accuracy: 0.6641 - 19ms/epoch - 2ms/step
# Epoch 98/50000
# 11/11 - 0s - loss: 0.8574 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 99/50000
# 11/11 - 0s - loss: 0.8453 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 100/50000
# 11/11 - 0s - loss: 0.8380 - accuracy: 0.6583 - 21ms/epoch - 2ms/step
# Epoch 101/50000
# 11/11 - 0s - loss: 0.8315 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 102/50000
# 11/11 - 0s - loss: 0.8348 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 103/50000
# 11/11 - 0s - loss: 0.8283 - accuracy: 0.6563 - 19ms/epoch - 2ms/step
# Epoch 104/50000
# 11/11 - 0s - loss: 0.8356 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 105/50000
# 11/11 - 0s - loss: 0.8276 - accuracy: 0.6680 - 17ms/epoch - 2ms/step
# Epoch 106/50000
# 11/11 - 0s - loss: 0.8390 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 107/50000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6505 - 19ms/epoch - 2ms/step
# Epoch 108/50000
# 11/11 - 0s - loss: 0.8412 - accuracy: 0.6641 - 18ms/epoch - 2ms/step
# Epoch 109/50000
# 11/11 - 0s - loss: 0.8524 - accuracy: 0.6408 - 19ms/epoch - 2ms/step
# Epoch 110/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 111/50000
# 11/11 - 0s - loss: 0.8597 - accuracy: 0.6485 - 20ms/epoch - 2ms/step
# Epoch 112/50000
# 11/11 - 0s - loss: 0.8425 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 113/50000
# 11/11 - 0s - loss: 0.8433 - accuracy: 0.6466 - 19ms/epoch - 2ms/step
# Epoch 114/50000
# 11/11 - 0s - loss: 0.8419 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 115/50000
# 11/11 - 0s - loss: 0.8350 - accuracy: 0.6544 - 21ms/epoch - 2ms/step
# Epoch 116/50000
# 11/11 - 0s - loss: 0.8354 - accuracy: 0.6621 - 21ms/epoch - 2ms/step
# Epoch 117/50000
# 11/11 - 0s - loss: 0.8549 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 118/50000
# 11/11 - 0s - loss: 0.8380 - accuracy: 0.6583 - 18ms/epoch - 2ms/step
# Epoch 119/50000
# 11/11 - 0s - loss: 0.8386 - accuracy: 0.6583 - 21ms/epoch - 2ms/step
# Epoch 120/50000
# 11/11 - 0s - loss: 0.8402 - accuracy: 0.6505 - 18ms/epoch - 2ms/step
# Epoch 121/50000
# 11/11 - 0s - loss: 0.8393 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 122/50000
# 11/11 - 0s - loss: 0.8332 - accuracy: 0.6660 - 19ms/epoch - 2ms/step
# Epoch 123/50000
# 11/11 - 0s - loss: 0.8316 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 124/50000
# 11/11 - 0s - loss: 0.8574 - accuracy: 0.6466 - 19ms/epoch - 2ms/step
# Epoch 125/50000
# 11/11 - 0s - loss: 0.8564 - accuracy: 0.6485 - 19ms/epoch - 2ms/step
# Epoch 126/50000
# 11/11 - 0s - loss: 0.8616 - accuracy: 0.6544 - 21ms/epoch - 2ms/step
# Epoch 127/50000
# 11/11 - 0s - loss: 0.8562 - accuracy: 0.6447 - 21ms/epoch - 2ms/step
# Epoch 128/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 129/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 130/50000
# 11/11 - 0s - loss: 0.8449 - accuracy: 0.6466 - 20ms/epoch - 2ms/step
# Epoch 131/50000
# 11/11 - 0s - loss: 0.8424 - accuracy: 0.6602 - 21ms/epoch - 2ms/step
# Epoch 132/50000
# 11/11 - 0s - loss: 0.8456 - accuracy: 0.6427 - 19ms/epoch - 2ms/step
# Epoch 133/50000
# 11/11 - 0s - loss: 0.8468 - accuracy: 0.6505 - 20ms/epoch - 2ms/step
# Epoch 134/50000
# 11/11 - 0s - loss: 0.8559 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 135/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6680 - 22ms/epoch - 2ms/step
# Epoch 136/50000
# 11/11 - 0s - loss: 0.8401 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 137/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6447 - 21ms/epoch - 2ms/step
# Epoch 138/50000
# 11/11 - 0s - loss: 0.8331 - accuracy: 0.6641 - 18ms/epoch - 2ms/step
# Epoch 139/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 140/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 141/50000
# 11/11 - 0s - loss: 0.8437 - accuracy: 0.6466 - 19ms/epoch - 2ms/step
# Epoch 142/50000
# 11/11 - 0s - loss: 0.8413 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 143/50000
# 11/11 - 0s - loss: 0.8519 - accuracy: 0.6388 - 18ms/epoch - 2ms/step
# Epoch 144/50000
# 11/11 - 0s - loss: 0.8460 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 145/50000
# 11/11 - 0s - loss: 0.8443 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 146/50000
# 11/11 - 0s - loss: 0.8406 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 147/50000
# 11/11 - 0s - loss: 0.8392 - accuracy: 0.6621 - 18ms/epoch - 2ms/step
# Epoch 148/50000
# 11/11 - 0s - loss: 0.8397 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 149/50000
# 11/11 - 0s - loss: 0.8430 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 150/50000
# 11/11 - 0s - loss: 0.8323 - accuracy: 0.6621 - 18ms/epoch - 2ms/step
# Epoch 151/50000
# 11/11 - 0s - loss: 0.8435 - accuracy: 0.6544 - 33ms/epoch - 3ms/step
# Epoch 152/50000
# 11/11 - 0s - loss: 0.8319 - accuracy: 0.6641 - 27ms/epoch - 2ms/step
# Epoch 153/50000
# 11/11 - 0s - loss: 0.8422 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 154/50000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 155/50000
# 11/11 - 0s - loss: 0.8314 - accuracy: 0.6621 - 15ms/epoch - 1ms/step
# Epoch 156/50000
# 11/11 - 0s - loss: 0.8269 - accuracy: 0.6641 - 17ms/epoch - 2ms/step
# Epoch 157/50000
# 11/11 - 0s - loss: 0.8319 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 158/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 159/50000
# 11/11 - 0s - loss: 0.8347 - accuracy: 0.6660 - 16ms/epoch - 1ms/step
# Epoch 160/50000
# 11/11 - 0s - loss: 0.8379 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 161/50000
# 11/11 - 0s - loss: 0.8342 - accuracy: 0.6621 - 15ms/epoch - 1ms/step
# Epoch 162/50000
# 11/11 - 0s - loss: 0.8354 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 163/50000
# 11/11 - 0s - loss: 0.8497 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 164/50000
# 11/11 - 0s - loss: 0.8444 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 165/50000
# 11/11 - 0s - loss: 0.8345 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 166/50000
# 11/11 - 0s - loss: 0.8487 - accuracy: 0.6524 - 16ms/epoch - 1ms/step
# Epoch 167/50000
# 11/11 - 0s - loss: 0.8441 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 168/50000
# 11/11 - 0s - loss: 0.8461 - accuracy: 0.6427 - 22ms/epoch - 2ms/step
# Epoch 169/50000
# 11/11 - 0s - loss: 0.8449 - accuracy: 0.6524 - 16ms/epoch - 1ms/step
# Epoch 170/50000
# 11/11 - 0s - loss: 0.8319 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 171/50000
# 11/11 - 0s - loss: 0.8509 - accuracy: 0.6505 - 14ms/epoch - 1ms/step
# Epoch 172/50000
# 11/11 - 0s - loss: 0.8449 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 173/50000
# 11/11 - 0s - loss: 0.8368 - accuracy: 0.6680 - 16ms/epoch - 1ms/step
# Epoch 174/50000
# 11/11 - 0s - loss: 0.8403 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 175/50000
# 11/11 - 0s - loss: 0.8445 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 176/50000
# 11/11 - 0s - loss: 0.8384 - accuracy: 0.6680 - 14ms/epoch - 1ms/step
# Epoch 177/50000
# 11/11 - 0s - loss: 0.8400 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 178/50000
# 11/11 - 0s - loss: 0.8429 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 179/50000
# 11/11 - 0s - loss: 0.8360 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 180/50000
# 11/11 - 0s - loss: 0.8324 - accuracy: 0.6602 - 16ms/epoch - 1ms/step
# Epoch 181/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 182/50000
# 11/11 - 0s - loss: 0.8358 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 183/50000
# 11/11 - 0s - loss: 0.8452 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 184/50000
# 11/11 - 0s - loss: 0.8501 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 185/50000
# 11/11 - 0s - loss: 0.8372 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 186/50000
# 11/11 - 0s - loss: 0.8461 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 187/50000
# 11/11 - 0s - loss: 0.8403 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 188/50000
# 11/11 - 0s - loss: 0.8412 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 189/50000
# 11/11 - 0s - loss: 0.8523 - accuracy: 0.6485 - 18ms/epoch - 2ms/step
# Epoch 190/50000
# 11/11 - 0s - loss: 0.8451 - accuracy: 0.6485 - 16ms/epoch - 1ms/step
# Epoch 191/50000
# 11/11 - 0s - loss: 0.8388 - accuracy: 0.6485 - 19ms/epoch - 2ms/step
# Epoch 192/50000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6583 - 34ms/epoch - 3ms/step
# Epoch 193/50000
# 11/11 - 0s - loss: 0.8492 - accuracy: 0.6485 - 29ms/epoch - 3ms/step
# Epoch 194/50000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 195/50000
# 11/11 - 0s - loss: 0.8453 - accuracy: 0.6388 - 12ms/epoch - 1ms/step
# Epoch 196/50000
# 11/11 - 0s - loss: 12.6734 - accuracy: 0.6485 - 14ms/epoch - 1ms/step
# Epoch 197/50000
# 11/11 - 0s - loss: 1.2073 - accuracy: 0.5631 - 14ms/epoch - 1ms/step
# Epoch 198/50000
# 11/11 - 0s - loss: 1.1564 - accuracy: 0.5728 - 14ms/epoch - 1ms/step
# Epoch 199/50000
# 11/11 - 0s - loss: 1.2061 - accuracy: 0.5806 - 14ms/epoch - 1ms/step
# Epoch 200/50000
# 11/11 - 0s - loss: 0.9903 - accuracy: 0.6194 - 16ms/epoch - 1ms/step
# Epoch 201/50000
# 11/11 - 0s - loss: 0.9382 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 202/50000
# 11/11 - 0s - loss: 0.9135 - accuracy: 0.6466 - 17ms/epoch - 2ms/step
# Epoch 203/50000
# 11/11 - 0s - loss: 0.9081 - accuracy: 0.6214 - 15ms/epoch - 1ms/step
# Epoch 204/50000
# 11/11 - 0s - loss: 0.8852 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 205/50000
# 11/11 - 0s - loss: 0.8657 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 206/50000
# 11/11 - 0s - loss: 0.8604 - accuracy: 0.6466 - 18ms/epoch - 2ms/step
# Epoch 207/50000
# 11/11 - 0s - loss: 0.8589 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 208/50000
# 11/11 - 0s - loss: 0.8537 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 209/50000
# 11/11 - 0s - loss: 0.8572 - accuracy: 0.6524 - 17ms/epoch - 2ms/step
# Epoch 210/50000
# 11/11 - 0s - loss: 0.8550 - accuracy: 0.6447 - 19ms/epoch - 2ms/step
# Epoch 211/50000
# 11/11 - 0s - loss: 0.8613 - accuracy: 0.6447 - 17ms/epoch - 2ms/step
# Epoch 212/50000
# 11/11 - 0s - loss: 0.8470 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 213/50000
# 11/11 - 0s - loss: 0.8571 - accuracy: 0.6485 - 19ms/epoch - 2ms/step
# Epoch 214/50000
# 11/11 - 0s - loss: 0.8539 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 215/50000
# 11/11 - 0s - loss: 0.8403 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 216/50000
# 11/11 - 0s - loss: 0.8476 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 217/50000
# 11/11 - 0s - loss: 0.8606 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 218/50000
# 11/11 - 0s - loss: 0.8508 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 219/50000
# 11/11 - 0s - loss: 0.8488 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 220/50000
# 11/11 - 0s - loss: 0.8416 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 221/50000
# 11/11 - 0s - loss: 0.8420 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 222/50000
# 11/11 - 0s - loss: 0.8407 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 223/50000
# 11/11 - 0s - loss: 0.8409 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 224/50000
# 11/11 - 0s - loss: 0.8416 - accuracy: 0.6583 - 27ms/epoch - 2ms/step
# Epoch 225/50000
# 11/11 - 0s - loss: 0.8521 - accuracy: 0.6544 - 33ms/epoch - 3ms/step
# Epoch 226/50000
# 11/11 - 0s - loss: 0.8535 - accuracy: 0.6583 - 22ms/epoch - 2ms/step
# Epoch 227/50000
# 11/11 - 0s - loss: 0.8382 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 228/50000
# 11/11 - 0s - loss: 0.8385 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 229/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 230/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 231/50000
# 11/11 - 0s - loss: 0.8398 - accuracy: 0.6641 - 13ms/epoch - 1ms/step
# Epoch 232/50000
# 11/11 - 0s - loss: 0.8443 - accuracy: 0.6524 - 13ms/epoch - 1ms/step
# Epoch 233/50000
# 11/11 - 0s - loss: 0.8360 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 234/50000
# 11/11 - 0s - loss: 0.8441 - accuracy: 0.6505 - 13ms/epoch - 1ms/step
# Epoch 235/50000
# 11/11 - 0s - loss: 0.8415 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 236/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6680 - 15ms/epoch - 1ms/step
# Epoch 237/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 238/50000
# 11/11 - 0s - loss: 0.8470 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 239/50000
# 11/11 - 0s - loss: 0.8555 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 240/50000
# 11/11 - 0s - loss: 0.8454 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 241/50000
# 11/11 - 0s - loss: 0.8405 - accuracy: 0.6602 - 16ms/epoch - 1ms/step
# Epoch 242/50000
# 11/11 - 0s - loss: 0.8417 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 243/50000
# 11/11 - 0s - loss: 0.8404 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 244/50000
# 11/11 - 0s - loss: 0.8385 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 245/50000
# 11/11 - 0s - loss: 0.8378 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 246/50000
# 11/11 - 0s - loss: 0.8389 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 247/50000
# 11/11 - 0s - loss: 0.8489 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 248/50000
# 11/11 - 0s - loss: 0.8454 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 249/50000
# 11/11 - 0s - loss: 0.8516 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 250/50000
# 11/11 - 0s - loss: 0.8957 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 251/50000
# 11/11 - 0s - loss: 0.8867 - accuracy: 0.6408 - 17ms/epoch - 2ms/step
# Epoch 252/50000
# 11/11 - 0s - loss: 0.8607 - accuracy: 0.6447 - 19ms/epoch - 2ms/step
# Epoch 253/50000
# 11/11 - 0s - loss: 0.8587 - accuracy: 0.6466 - 19ms/epoch - 2ms/step
# Epoch 254/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 255/50000
# 11/11 - 0s - loss: 0.8342 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 256/50000
# 11/11 - 0s - loss: 0.8338 - accuracy: 0.6641 - 17ms/epoch - 2ms/step
# Epoch 257/50000
# 11/11 - 0s - loss: 0.8533 - accuracy: 0.6602 - 19ms/epoch - 2ms/step
# Epoch 258/50000
# 11/11 - 0s - loss: 0.8461 - accuracy: 0.6680 - 19ms/epoch - 2ms/step
# Epoch 259/50000
# 11/11 - 0s - loss: 0.8425 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 260/50000
# 11/11 - 0s - loss: 0.8533 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 261/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6544 - 20ms/epoch - 2ms/step
# Epoch 262/50000
# 11/11 - 0s - loss: 0.8437 - accuracy: 0.6563 - 21ms/epoch - 2ms/step
# Epoch 263/50000
# 11/11 - 0s - loss: 0.8412 - accuracy: 0.6485 - 19ms/epoch - 2ms/step
# Epoch 264/50000
# 11/11 - 0s - loss: 0.8437 - accuracy: 0.6563 - 20ms/epoch - 2ms/step
# Epoch 265/50000
# 11/11 - 0s - loss: 0.8445 - accuracy: 0.6505 - 20ms/epoch - 2ms/step
# Epoch 266/50000
# 11/11 - 0s - loss: 0.8508 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 267/50000
# 11/11 - 0s - loss: 0.8561 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 268/50000
# 11/11 - 0s - loss: 0.8494 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 269/50000
# 11/11 - 0s - loss: 0.8427 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 270/50000
# 11/11 - 0s - loss: 0.8427 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 271/50000
# 11/11 - 0s - loss: 0.8345 - accuracy: 0.6621 - 16ms/epoch - 1ms/step
# Epoch 272/50000
# 11/11 - 0s - loss: 0.8712 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 273/50000
# 11/11 - 0s - loss: 0.8555 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 274/50000
# 11/11 - 0s - loss: 0.8691 - accuracy: 0.6505 - 16ms/epoch - 1ms/step
# Epoch 275/50000
# 11/11 - 0s - loss: 0.8518 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 276/50000
# 11/11 - 0s - loss: 0.9319 - accuracy: 0.6194 - 16ms/epoch - 1ms/step
# Epoch 277/50000
# 11/11 - 0s - loss: 0.9855 - accuracy: 0.6214 - 17ms/epoch - 2ms/step
# Epoch 278/50000
# 11/11 - 0s - loss: 0.9318 - accuracy: 0.6369 - 14ms/epoch - 1ms/step
# Epoch 279/50000
# 11/11 - 0s - loss: 0.8774 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 280/50000
# 11/11 - 0s - loss: 0.8689 - accuracy: 0.6408 - 17ms/epoch - 2ms/step
# Epoch 281/50000
# 11/11 - 0s - loss: 0.8534 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 282/50000
# 11/11 - 0s - loss: 0.8462 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 283/50000
# 11/11 - 0s - loss: 0.8471 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 284/50000
# 11/11 - 0s - loss: 0.8513 - accuracy: 0.6447 - 14ms/epoch - 1ms/step
# Epoch 285/50000
# 11/11 - 0s - loss: 0.8406 - accuracy: 0.6583 - 30ms/epoch - 3ms/step
# Epoch 286/50000
# 11/11 - 0s - loss: 0.8366 - accuracy: 0.6563 - 37ms/epoch - 3ms/step
# Epoch 287/50000
# 11/11 - 0s - loss: 0.8354 - accuracy: 0.6583 - 22ms/epoch - 2ms/step
# Epoch 288/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6621 - 18ms/epoch - 2ms/step
# Epoch 289/50000
# 11/11 - 0s - loss: 0.8406 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 290/50000
# 11/11 - 0s - loss: 0.8379 - accuracy: 0.6466 - 14ms/epoch - 1ms/step
# Epoch 291/50000
# 11/11 - 0s - loss: 0.8400 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 292/50000
# 11/11 - 0s - loss: 0.8458 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 293/50000
# 11/11 - 0s - loss: 0.8335 - accuracy: 0.6621 - 13ms/epoch - 1ms/step
# Epoch 294/50000
# 11/11 - 0s - loss: 0.8376 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 295/50000
# 11/11 - 0s - loss: 0.8313 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 296/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 297/50000
# 11/11 - 0s - loss: 0.8347 - accuracy: 0.6738 - 18ms/epoch - 2ms/step
# Epoch 298/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 299/50000
# 11/11 - 0s - loss: 0.8405 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 300/50000
# 11/11 - 0s - loss: 0.8380 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 301/50000
# 11/11 - 0s - loss: 0.8304 - accuracy: 0.6660 - 13ms/epoch - 1ms/step
# Epoch 302/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 303/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 304/50000
# 11/11 - 0s - loss: 0.8409 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 305/50000
# 11/11 - 0s - loss: 0.8339 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 306/50000
# 11/11 - 0s - loss: 0.8323 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 307/50000
# 11/11 - 0s - loss: 0.8333 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 308/50000
# 11/11 - 0s - loss: 0.8344 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 309/50000
# 11/11 - 0s - loss: 0.8320 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 310/50000
# 11/11 - 0s - loss: 0.8375 - accuracy: 0.6544 - 19ms/epoch - 2ms/step
# Epoch 311/50000
# 11/11 - 0s - loss: 0.8521 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 312/50000
# 11/11 - 0s - loss: 0.8650 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 313/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 314/50000
# 11/11 - 0s - loss: 0.8323 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 315/50000
# 11/11 - 0s - loss: 0.8473 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 316/50000
# 11/11 - 0s - loss: 0.8456 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 317/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 318/50000
# 11/11 - 0s - loss: 0.8324 - accuracy: 0.6621 - 18ms/epoch - 2ms/step
# Epoch 319/50000
# 11/11 - 0s - loss: 0.8334 - accuracy: 0.6602 - 21ms/epoch - 2ms/step
# Epoch 320/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6505 - 24ms/epoch - 2ms/step
# Epoch 321/50000
# 11/11 - 0s - loss: 0.8325 - accuracy: 0.6583 - 25ms/epoch - 2ms/step
# Epoch 322/50000
# 11/11 - 0s - loss: 0.8716 - accuracy: 0.6505 - 19ms/epoch - 2ms/step
# Epoch 323/50000
# 11/11 - 0s - loss: 0.8579 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 324/50000
# 11/11 - 0s - loss: 0.8434 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 325/50000
# 11/11 - 0s - loss: 0.8382 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 326/50000
# 11/11 - 0s - loss: 0.8478 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 327/50000
# 11/11 - 0s - loss: 0.8357 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 328/50000
# 11/11 - 0s - loss: 0.8381 - accuracy: 0.6699 - 17ms/epoch - 2ms/step
# Epoch 329/50000
# 11/11 - 0s - loss: 0.8386 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 330/50000
# 11/11 - 0s - loss: 0.8500 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 331/50000
# 11/11 - 0s - loss: 0.8510 - accuracy: 0.6466 - 24ms/epoch - 2ms/step
# Epoch 332/50000
# 11/11 - 0s - loss: 0.8439 - accuracy: 0.6602 - 29ms/epoch - 3ms/step
# Epoch 333/50000
# 11/11 - 0s - loss: 0.8425 - accuracy: 0.6602 - 28ms/epoch - 3ms/step
# Epoch 334/50000
# 11/11 - 0s - loss: 0.8379 - accuracy: 0.6660 - 16ms/epoch - 1ms/step
# Epoch 335/50000
# 11/11 - 0s - loss: 0.8366 - accuracy: 0.6602 - 16ms/epoch - 1ms/step
# Epoch 336/50000
# 11/11 - 0s - loss: 0.8421 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 337/50000
# 11/11 - 0s - loss: 0.8353 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 338/50000
# 11/11 - 0s - loss: 0.8309 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 339/50000
# 11/11 - 0s - loss: 0.8325 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 340/50000
# 11/11 - 0s - loss: 0.8469 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 341/50000
# 11/11 - 0s - loss: 0.8677 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 342/50000
# 11/11 - 0s - loss: 0.8516 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 343/50000
# 11/11 - 0s - loss: 0.8429 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 344/50000
# 11/11 - 0s - loss: 0.8398 - accuracy: 0.6602 - 17ms/epoch - 2ms/step
# Epoch 345/50000
# 11/11 - 0s - loss: 0.8295 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 346/50000
# 11/11 - 0s - loss: 0.8357 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 347/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 348/50000
# 11/11 - 0s - loss: 0.8377 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 349/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6505 - 16ms/epoch - 1ms/step
# Epoch 350/50000
# 11/11 - 0s - loss: 0.8317 - accuracy: 0.6660 - 15ms/epoch - 1ms/step
# Epoch 351/50000
# 11/11 - 0s - loss: 0.8470 - accuracy: 0.6621 - 16ms/epoch - 1ms/step
# Epoch 352/50000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 353/50000
# 11/11 - 0s - loss: 0.8697 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 354/50000
# 11/11 - 0s - loss: 0.8376 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 355/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 356/50000
# 11/11 - 0s - loss: 0.8417 - accuracy: 0.6621 - 26ms/epoch - 2ms/step
# Epoch 357/50000
# 11/11 - 0s - loss: 0.8352 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 358/50000
# 11/11 - 0s - loss: 0.8278 - accuracy: 0.6621 - 15ms/epoch - 1ms/step
# Epoch 359/50000
# 11/11 - 0s - loss: 0.8359 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 360/50000
# 11/11 - 0s - loss: 0.8524 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 361/50000
# 11/11 - 0s - loss: 0.8411 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 362/50000
# 11/11 - 0s - loss: 0.8339 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 363/50000
# 11/11 - 0s - loss: 0.8382 - accuracy: 0.6660 - 18ms/epoch - 2ms/step
# Epoch 364/50000
# 11/11 - 0s - loss: 0.8471 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 365/50000
# 11/11 - 0s - loss: 0.8402 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 366/50000
# 11/11 - 0s - loss: 0.8454 - accuracy: 0.6485 - 19ms/epoch - 2ms/step
# Epoch 367/50000
# 11/11 - 0s - loss: 0.8575 - accuracy: 0.6466 - 18ms/epoch - 2ms/step
# Epoch 368/50000
# 11/11 - 0s - loss: 0.8602 - accuracy: 0.6563 - 19ms/epoch - 2ms/step
# Epoch 369/50000
# 11/11 - 0s - loss: 0.8551 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 370/50000
# 11/11 - 0s - loss: 0.8451 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 371/50000
# 11/11 - 0s - loss: 0.8381 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 372/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6621 - 16ms/epoch - 1ms/step
# Epoch 373/50000
# 11/11 - 0s - loss: 0.8341 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 374/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 375/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6602 - 20ms/epoch - 2ms/step
# Epoch 376/50000
# 11/11 - 0s - loss: 0.8490 - accuracy: 0.6447 - 33ms/epoch - 3ms/step
# Epoch 377/50000
# 11/11 - 0s - loss: 0.8409 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 378/50000
# 11/11 - 0s - loss: 0.8458 - accuracy: 0.6583 - 21ms/epoch - 2ms/step
# Epoch 379/50000
# 11/11 - 0s - loss: 0.8437 - accuracy: 0.6583 - 25ms/epoch - 2ms/step
# Epoch 380/50000
# 11/11 - 0s - loss: 0.8381 - accuracy: 0.6680 - 21ms/epoch - 2ms/step
# Epoch 381/50000
# 11/11 - 0s - loss: 0.8378 - accuracy: 0.6602 - 21ms/epoch - 2ms/step
# Epoch 382/50000
# 11/11 - 0s - loss: 0.8295 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 383/50000
# 11/11 - 0s - loss: 0.8317 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 384/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6583 - 13ms/epoch - 1ms/step
# Epoch 385/50000
# 11/11 - 0s - loss: 0.8431 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 386/50000
# 11/11 - 0s - loss: 0.8527 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 387/50000
# 11/11 - 0s - loss: 0.8403 - accuracy: 0.6524 - 14ms/epoch - 1ms/step
# Epoch 388/50000
# 11/11 - 0s - loss: 0.9158 - accuracy: 0.6369 - 15ms/epoch - 1ms/step
# Epoch 389/50000
# 11/11 - 0s - loss: 1.1236 - accuracy: 0.6000 - 14ms/epoch - 1ms/step
# Epoch 390/50000
# 11/11 - 0s - loss: 0.9271 - accuracy: 0.6350 - 15ms/epoch - 1ms/step
# Epoch 391/50000
# 11/11 - 0s - loss: 0.9034 - accuracy: 0.6350 - 15ms/epoch - 1ms/step
# Epoch 392/50000
# 11/11 - 0s - loss: 0.8678 - accuracy: 0.6427 - 14ms/epoch - 1ms/step
# Epoch 393/50000
# 11/11 - 0s - loss: 0.8482 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 394/50000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6602 - 16ms/epoch - 1ms/step
# Epoch 395/50000
# 11/11 - 0s - loss: 0.8341 - accuracy: 0.6660 - 15ms/epoch - 1ms/step
# Epoch 396/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 397/50000
# 11/11 - 0s - loss: 0.8345 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 398/50000
# 11/11 - 0s - loss: 0.8391 - accuracy: 0.6524 - 19ms/epoch - 2ms/step
# Epoch 399/50000
# 11/11 - 0s - loss: 0.8302 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 400/50000
# 11/11 - 0s - loss: 0.8366 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 401/50000
# 11/11 - 0s - loss: 0.8349 - accuracy: 0.6680 - 18ms/epoch - 2ms/step
# Epoch 402/50000
# 11/11 - 0s - loss: 0.8378 - accuracy: 0.6621 - 16ms/epoch - 1ms/step
# Epoch 403/50000
# 11/11 - 0s - loss: 0.8289 - accuracy: 0.6641 - 19ms/epoch - 2ms/step
# Epoch 404/50000
# 11/11 - 0s - loss: 0.8335 - accuracy: 0.6583 - 19ms/epoch - 2ms/step
# Epoch 405/50000
# 11/11 - 0s - loss: 0.8337 - accuracy: 0.6621 - 18ms/epoch - 2ms/step
# Epoch 406/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6621 - 19ms/epoch - 2ms/step
# Epoch 407/50000
# 11/11 - 0s - loss: 0.8377 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 408/50000
# 11/11 - 0s - loss: 0.8427 - accuracy: 0.6563 - 17ms/epoch - 2ms/step
# Epoch 409/50000
# 11/11 - 0s - loss: 0.8331 - accuracy: 0.6524 - 16ms/epoch - 1ms/step
# Epoch 410/50000
# 11/11 - 0s - loss: 0.8314 - accuracy: 0.6485 - 17ms/epoch - 2ms/step
# Epoch 411/50000
# 11/11 - 0s - loss: 0.8345 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 412/50000
# 11/11 - 0s - loss: 0.8359 - accuracy: 0.6641 - 17ms/epoch - 2ms/step
# Epoch 413/50000
# 11/11 - 0s - loss: 0.8316 - accuracy: 0.6563 - 20ms/epoch - 2ms/step
# Epoch 414/50000
# 11/11 - 0s - loss: 0.8742 - accuracy: 0.6408 - 17ms/epoch - 2ms/step
# Epoch 415/50000
# 11/11 - 0s - loss: 0.8528 - accuracy: 0.6466 - 25ms/epoch - 2ms/step
# Epoch 416/50000
# 11/11 - 0s - loss: 0.8343 - accuracy: 0.6583 - 38ms/epoch - 3ms/step
# Epoch 417/50000
# 11/11 - 0s - loss: 0.8533 - accuracy: 0.6544 - 17ms/epoch - 2ms/step
# Epoch 418/50000
# 11/11 - 0s - loss: 0.8391 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 419/50000
# 11/11 - 0s - loss: 0.8364 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 420/50000
# 11/11 - 0s - loss: 0.8370 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 421/50000
# 11/11 - 0s - loss: 0.8328 - accuracy: 0.6660 - 17ms/epoch - 2ms/step
# Epoch 422/50000
# 11/11 - 0s - loss: 0.8313 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 423/50000
# 11/11 - 0s - loss: 0.8369 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 424/50000
# 11/11 - 0s - loss: 0.8388 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 425/50000
# 11/11 - 0s - loss: 0.8312 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 426/50000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 427/50000
# 11/11 - 0s - loss: 0.8351 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 428/50000
# 11/11 - 0s - loss: 0.8310 - accuracy: 0.6621 - 13ms/epoch - 1ms/step
# Epoch 429/50000
# 11/11 - 0s - loss: 0.8367 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 430/50000
# 11/11 - 0s - loss: 0.8290 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 431/50000
# 11/11 - 0s - loss: 0.8311 - accuracy: 0.6505 - 16ms/epoch - 1ms/step
# Epoch 432/50000
# 11/11 - 0s - loss: 0.8428 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 433/50000
# 11/11 - 0s - loss: 0.8498 - accuracy: 0.6524 - 16ms/epoch - 1ms/step
# Epoch 434/50000
# 11/11 - 0s - loss: 0.8389 - accuracy: 0.6524 - 15ms/epoch - 1ms/step
# Epoch 435/50000
# 11/11 - 0s - loss: 0.8292 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 436/50000
# 11/11 - 0s - loss: 0.8439 - accuracy: 0.6563 - 17ms/epoch - 2ms/step
# Epoch 437/50000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 438/50000
# 11/11 - 0s - loss: 0.8354 - accuracy: 0.6505 - 14ms/epoch - 1ms/step
# Epoch 439/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6563 - 13ms/epoch - 1ms/step
# Epoch 440/50000
# 11/11 - 0s - loss: 0.8398 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 441/50000
# 11/11 - 0s - loss: 0.8406 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 442/50000
# 11/11 - 0s - loss: 0.8286 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 443/50000
# 11/11 - 0s - loss: 0.8323 - accuracy: 0.6660 - 15ms/epoch - 1ms/step
# Epoch 444/50000
# 11/11 - 0s - loss: 0.8326 - accuracy: 0.6621 - 15ms/epoch - 1ms/step
# Epoch 445/50000
# 11/11 - 0s - loss: 0.8294 - accuracy: 0.6544 - 18ms/epoch - 2ms/step
# Epoch 446/50000
# 11/11 - 0s - loss: 0.8327 - accuracy: 0.6583 - 20ms/epoch - 2ms/step
# Epoch 447/50000
# 11/11 - 0s - loss: 0.8307 - accuracy: 0.6583 - 17ms/epoch - 2ms/step
# Epoch 448/50000
# 11/11 - 0s - loss: 0.8293 - accuracy: 0.6621 - 15ms/epoch - 1ms/step
# Epoch 449/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6524 - 20ms/epoch - 2ms/step
# Epoch 450/50000
# 11/11 - 0s - loss: 0.8459 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 451/50000
# 11/11 - 0s - loss: 0.8435 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 452/50000
# 11/11 - 0s - loss: 0.8405 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 453/50000
# 11/11 - 0s - loss: 0.8312 - accuracy: 0.6505 - 18ms/epoch - 2ms/step
# Epoch 454/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6602 - 17ms/epoch - 2ms/step
# Epoch 455/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6641 - 15ms/epoch - 1ms/step
# Epoch 456/50000
# 11/11 - 0s - loss: 0.8371 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 457/50000
# 11/11 - 0s - loss: 0.8461 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 458/50000
# 11/11 - 0s - loss: 0.8354 - accuracy: 0.6660 - 13ms/epoch - 1ms/step
# Epoch 459/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6680 - 14ms/epoch - 1ms/step
# Epoch 460/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 461/50000
# 11/11 - 0s - loss: 0.8364 - accuracy: 0.6583 - 12ms/epoch - 1ms/step
# Epoch 462/50000
# 11/11 - 0s - loss: 0.8373 - accuracy: 0.6583 - 13ms/epoch - 1ms/step
# Epoch 463/50000
# 11/11 - 0s - loss: 0.8355 - accuracy: 0.6660 - 13ms/epoch - 1ms/step
# Epoch 464/50000
# 11/11 - 0s - loss: 0.8320 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 465/50000
# 11/11 - 0s - loss: 0.8374 - accuracy: 0.6563 - 13ms/epoch - 1ms/step
# Epoch 466/50000
# 11/11 - 0s - loss: 0.8440 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 467/50000
# 11/11 - 0s - loss: 0.8589 - accuracy: 0.6524 - 13ms/epoch - 1ms/step
# Epoch 468/50000
# 11/11 - 0s - loss: 0.8371 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 469/50000
# 11/11 - 0s - loss: 0.8443 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 470/50000
# 11/11 - 0s - loss: 0.8312 - accuracy: 0.6718 - 14ms/epoch - 1ms/step
# Epoch 471/50000
# 11/11 - 0s - loss: 0.8341 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 472/50000
# 11/11 - 0s - loss: 0.8352 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 473/50000
# 11/11 - 0s - loss: 0.8351 - accuracy: 0.6602 - 17ms/epoch - 2ms/step
# Epoch 474/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 475/50000
# 11/11 - 0s - loss: 1.1068 - accuracy: 0.6136 - 18ms/epoch - 2ms/step
# Epoch 476/50000
# 11/11 - 0s - loss: 0.9192 - accuracy: 0.6311 - 19ms/epoch - 2ms/step
# Epoch 477/50000
# 11/11 - 0s - loss: 0.8743 - accuracy: 0.6466 - 23ms/epoch - 2ms/step
# Epoch 478/50000
# 11/11 - 0s - loss: 0.8499 - accuracy: 0.6505 - 23ms/epoch - 2ms/step
# Epoch 479/50000
# 11/11 - 0s - loss: 0.8463 - accuracy: 0.6505 - 19ms/epoch - 2ms/step
# Epoch 480/50000
# 11/11 - 0s - loss: 0.8413 - accuracy: 0.6602 - 18ms/epoch - 2ms/step
# Epoch 481/50000
# 11/11 - 0s - loss: 0.8301 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 482/50000
# 11/11 - 0s - loss: 0.8349 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 483/50000
# 11/11 - 0s - loss: 0.8390 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 484/50000
# 11/11 - 0s - loss: 0.8375 - accuracy: 0.6583 - 15ms/epoch - 1ms/step
# Epoch 485/50000
# 11/11 - 0s - loss: 0.8353 - accuracy: 0.6718 - 16ms/epoch - 1ms/step
# Epoch 486/50000
# 11/11 - 0s - loss: 0.8385 - accuracy: 0.6524 - 17ms/epoch - 2ms/step
# Epoch 487/50000
# 11/11 - 0s - loss: 0.8549 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 488/50000
# 11/11 - 0s - loss: 0.8399 - accuracy: 0.6641 - 16ms/epoch - 1ms/step
# Epoch 489/50000
# 11/11 - 0s - loss: 0.8349 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 490/50000
# 11/11 - 0s - loss: 0.8395 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 491/50000
# 11/11 - 0s - loss: 0.8428 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 492/50000
# 11/11 - 0s - loss: 0.8311 - accuracy: 0.6680 - 12ms/epoch - 1ms/step
# Epoch 493/50000
# 11/11 - 0s - loss: 0.8441 - accuracy: 0.6583 - 13ms/epoch - 1ms/step
# Epoch 494/50000
# 11/11 - 0s - loss: 0.8498 - accuracy: 0.6602 - 13ms/epoch - 1ms/step
# Epoch 495/50000
# 11/11 - 0s - loss: 0.8308 - accuracy: 0.6621 - 13ms/epoch - 1ms/step
# Epoch 496/50000
# 11/11 - 0s - loss: 0.8365 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 497/50000
# 11/11 - 0s - loss: 0.8385 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 498/50000
# 11/11 - 0s - loss: 0.8410 - accuracy: 0.6524 - 16ms/epoch - 1ms/step
# Epoch 499/50000
# 11/11 - 0s - loss: 0.8500 - accuracy: 0.6485 - 22ms/epoch - 2ms/step
# Epoch 500/50000
# 11/11 - 0s - loss: 0.8424 - accuracy: 0.6583 - 21ms/epoch - 2ms/step
# Epoch 501/50000
# 11/11 - 0s - loss: 0.8420 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 502/50000
# 11/11 - 0s - loss: 0.8325 - accuracy: 0.6699 - 18ms/epoch - 2ms/step
# Epoch 503/50000
# 11/11 - 0s - loss: 0.8355 - accuracy: 0.6602 - 17ms/epoch - 2ms/step
# Epoch 504/50000
# 11/11 - 0s - loss: 0.8283 - accuracy: 0.6602 - 15ms/epoch - 1ms/step
# Epoch 505/50000
# 11/11 - 0s - loss: 0.8361 - accuracy: 0.6544 - 15ms/epoch - 1ms/step
# Epoch 506/50000
# 11/11 - 0s - loss: 0.8418 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 507/50000
# 11/11 - 0s - loss: 0.8300 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 508/50000
# 11/11 - 0s - loss: 0.8304 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 509/50000
# 11/11 - 0s - loss: 0.8308 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 510/50000
# 11/11 - 0s - loss: 0.8324 - accuracy: 0.6583 - 13ms/epoch - 1ms/step
# Epoch 511/50000
# 11/11 - 0s - loss: 0.8305 - accuracy: 0.6718 - 13ms/epoch - 1ms/step
# Epoch 512/50000
# 11/11 - 0s - loss: 0.8336 - accuracy: 0.6602 - 13ms/epoch - 1ms/step
# Epoch 513/50000
# 11/11 - 0s - loss: 0.8301 - accuracy: 0.6563 - 13ms/epoch - 1ms/step
# Epoch 514/50000
# 11/11 - 0s - loss: 0.8446 - accuracy: 0.6485 - 14ms/epoch - 1ms/step
# Epoch 515/50000
# 11/11 - 0s - loss: 0.8320 - accuracy: 0.6699 - 15ms/epoch - 1ms/step
# Epoch 516/50000
# 11/11 - 0s - loss: 0.8372 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 517/50000
# 11/11 - 0s - loss: 0.8324 - accuracy: 0.6524 - 14ms/epoch - 1ms/step
# Epoch 518/50000
# 11/11 - 0s - loss: 0.8346 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 519/50000
# 11/11 - 0s - loss: 0.8352 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 520/50000
# 11/11 - 0s - loss: 0.8337 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 521/50000
# 11/11 - 0s - loss: 0.8256 - accuracy: 0.6621 - 19ms/epoch - 2ms/step
# Epoch 522/50000
# 11/11 - 0s - loss: 0.8289 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 523/50000
# 11/11 - 0s - loss: 0.8310 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 524/50000
# 11/11 - 0s - loss: 0.8442 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 525/50000
# 11/11 - 0s - loss: 0.8448 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 526/50000
# 11/11 - 0s - loss: 0.8342 - accuracy: 0.6641 - 18ms/epoch - 2ms/step
# Epoch 527/50000
# 11/11 - 0s - loss: 0.8433 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 528/50000
# 11/11 - 0s - loss: 0.8535 - accuracy: 0.6505 - 17ms/epoch - 2ms/step
# Epoch 529/50000
# 11/11 - 0s - loss: 0.8340 - accuracy: 0.6583 - 18ms/epoch - 2ms/step
# Epoch 530/50000
# 11/11 - 0s - loss: 0.8327 - accuracy: 0.6621 - 17ms/epoch - 2ms/step
# Epoch 531/50000
# 11/11 - 0s - loss: 0.8347 - accuracy: 0.6660 - 17ms/epoch - 2ms/step
# Epoch 532/50000
# 11/11 - 0s - loss: 0.8362 - accuracy: 0.6680 - 17ms/epoch - 2ms/step
# Epoch 533/50000
# 11/11 - 0s - loss: 0.8297 - accuracy: 0.6563 - 18ms/epoch - 2ms/step
# Epoch 534/50000
# 11/11 - 0s - loss: 0.8402 - accuracy: 0.6699 - 15ms/epoch - 1ms/step
# Epoch 535/50000
# 11/11 - 0s - loss: 0.8319 - accuracy: 0.6563 - 17ms/epoch - 2ms/step
# Epoch 536/50000
# 11/11 - 0s - loss: 0.8356 - accuracy: 0.6680 - 15ms/epoch - 1ms/step
# Epoch 537/50000
# 11/11 - 0s - loss: 0.8485 - accuracy: 0.6583 - 16ms/epoch - 1ms/step
# Epoch 538/50000
# 11/11 - 0s - loss: 0.8302 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 539/50000
# 11/11 - 0s - loss: 0.8363 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 540/50000
# 11/11 - 0s - loss: 0.8341 - accuracy: 0.6660 - 14ms/epoch - 1ms/step
# Epoch 541/50000
# 11/11 - 0s - loss: 0.8432 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 542/50000
# 11/11 - 0s - loss: 0.8427 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 543/50000
# 11/11 - 0s - loss: 0.8421 - accuracy: 0.6544 - 16ms/epoch - 1ms/step
# Epoch 544/50000
# 11/11 - 0s - loss: 0.8297 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 545/50000
# 11/11 - 0s - loss: 0.8299 - accuracy: 0.6621 - 13ms/epoch - 1ms/step
# Epoch 546/50000
# 11/11 - 0s - loss: 0.8325 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 547/50000
# 11/11 - 0s - loss: 0.8383 - accuracy: 0.6699 - 14ms/epoch - 1ms/step
# Epoch 548/50000
# 11/11 - 0s - loss: 0.8396 - accuracy: 0.6583 - 14ms/epoch - 1ms/step
# Epoch 549/50000
# 11/11 - 0s - loss: 0.8371 - accuracy: 0.6602 - 13ms/epoch - 1ms/step
# Epoch 550/50000
# 11/11 - 0s - loss: 0.8394 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 551/50000
# 11/11 - 0s - loss: 0.8284 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 552/50000
# 11/11 - 0s - loss: 0.8356 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 553/50000
# 11/11 - 0s - loss: 0.8503 - accuracy: 0.6563 - 15ms/epoch - 1ms/step
# Epoch 554/50000
# 11/11 - 0s - loss: 0.8465 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 555/50000
# 11/11 - 0s - loss: 0.8477 - accuracy: 0.6660 - 14ms/epoch - 1ms/step
# Epoch 556/50000
# 11/11 - 0s - loss: 0.8321 - accuracy: 0.6602 - 14ms/epoch - 1ms/step
# Epoch 557/50000
# 11/11 - 0s - loss: 0.8374 - accuracy: 0.6544 - 14ms/epoch - 1ms/step
# Epoch 558/50000
# 11/11 - 0s - loss: 0.8279 - accuracy: 0.6505 - 13ms/epoch - 1ms/step
# Epoch 559/50000
# 11/11 - 0s - loss: 0.8291 - accuracy: 0.6602 - 13ms/epoch - 1ms/step
# Epoch 560/50000
# 11/11 - 0s - loss: 0.8273 - accuracy: 0.6621 - 14ms/epoch - 1ms/step
# Epoch 561/50000
# 11/11 - 0s - loss: 0.8306 - accuracy: 0.6641 - 13ms/epoch - 1ms/step
# Epoch 562/50000
# 11/11 - 0s - loss: 0.8414 - accuracy: 0.6563 - 13ms/epoch - 1ms/step
# Epoch 563/50000
# 11/11 - 0s - loss: 0.8315 - accuracy: 0.6544 - 13ms/epoch - 1ms/step
# Epoch 564/50000
# 11/11 - 0s - loss: 0.8314 - accuracy: 0.6641 - 14ms/epoch - 1ms/step
# Epoch 565/50000
# 11/11 - 0s - loss: 0.8407 - accuracy: 0.6602 - 13ms/epoch - 1ms/step
# Epoch 566/50000
# ...
# Epoch 24799/50000
# 11/11 - 0s - loss: 0.9496 - accuracy: 0.6272 - 17ms/epoch - 2ms/step
# Epoch 24800/50000
# 11/11 - 0s - loss: 0.9593 - accuracy: 0.6311 - 16ms/epoch - 1ms/step
# Epoch 24801/50000
# 11/11 - 0s - loss: 0.9495 - accuracy: 0.6350 - 16ms/epoch - 1ms/step
# Epoch 24802/50000
# 11/11 - 0s - loss: 0.9425 - accuracy: 0.6330 - 15ms/epoch - 1ms/step
# Epoch 24803/50000
# 11/11 - 0s - loss: 0.9306 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 24804/50000
# 11/11 - 0s - loss: 0.9399 - accuracy: 0.6330 - 15ms/epoch - 1ms/step
# Epoch 24805/50000
# 11/11 - 0s - loss: 0.9505 - accuracy: 0.6272 - 14ms/epoch - 1ms/step
# Epoch 24806/50000
# 11/11 - 0s - loss: 0.9371 - accuracy: 0.6505 - 14ms/epoch - 1ms/step
# Epoch 24807/50000
# 11/11 - 0s - loss: 0.9327 - accuracy: 0.6408 - 14ms/epoch - 1ms/step
# Epoch 24808/50000
# 11/11 - 0s - loss: 0.9420 - accuracy: 0.6311 - 14ms/epoch - 1ms/step
# Epoch 24809/50000
# 11/11 - 0s - loss: 0.9391 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24810/50000
# 11/11 - 0s - loss: 0.9381 - accuracy: 0.6369 - 15ms/epoch - 1ms/step
# Epoch 24811/50000
# 11/11 - 0s - loss: 0.9454 - accuracy: 0.6408 - 17ms/epoch - 2ms/step
# Epoch 24812/50000
# 11/11 - 0s - loss: 0.9407 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24813/50000
# 11/11 - 0s - loss: 0.9487 - accuracy: 0.6369 - 17ms/epoch - 2ms/step
# Epoch 24814/50000
# 11/11 - 0s - loss: 0.9311 - accuracy: 0.6524 - 17ms/epoch - 2ms/step
# Epoch 24815/50000
# 11/11 - 0s - loss: 0.9424 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24816/50000
# 11/11 - 0s - loss: 0.9618 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24817/50000
# 11/11 - 0s - loss: 0.9561 - accuracy: 0.6330 - 17ms/epoch - 2ms/step
# Epoch 24818/50000
# 11/11 - 0s - loss: 0.9389 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24819/50000
# 11/11 - 0s - loss: 0.9397 - accuracy: 0.6427 - 16ms/epoch - 1ms/step
# Epoch 24820/50000
# 11/11 - 0s - loss: 0.9313 - accuracy: 0.6524 - 18ms/epoch - 2ms/step
# Epoch 24821/50000
# 11/11 - 0s - loss: 0.9442 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24822/50000
# 11/11 - 0s - loss: 0.9305 - accuracy: 0.6427 - 16ms/epoch - 1ms/step
# Epoch 24823/50000
# 11/11 - 0s - loss: 0.9358 - accuracy: 0.6427 - 17ms/epoch - 2ms/step
# Epoch 24824/50000
# 11/11 - 0s - loss: 0.9348 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 24825/50000
# 11/11 - 0s - loss: 0.9338 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24826/50000
# 11/11 - 0s - loss: 0.9339 - accuracy: 0.6563 - 14ms/epoch - 1ms/step
# Epoch 24827/50000
# 11/11 - 0s - loss: 0.9352 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24828/50000
# 11/11 - 0s - loss: 0.9335 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24829/50000
# 11/11 - 0s - loss: 0.9382 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24830/50000
# 11/11 - 0s - loss: 0.9300 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 24831/50000
# 11/11 - 0s - loss: 0.9453 - accuracy: 0.6447 - 16ms/epoch - 1ms/step
# Epoch 24832/50000
# 11/11 - 0s - loss: 0.9559 - accuracy: 0.6350 - 15ms/epoch - 1ms/step
# Epoch 24833/50000
# 11/11 - 0s - loss: 0.9425 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24834/50000
# 11/11 - 0s - loss: 0.9754 - accuracy: 0.6252 - 18ms/epoch - 2ms/step
# Epoch 24835/50000
# 11/11 - 0s - loss: 0.9734 - accuracy: 0.6369 - 19ms/epoch - 2ms/step
# Epoch 24836/50000
# 11/11 - 0s - loss: 0.9750 - accuracy: 0.6233 - 15ms/epoch - 1ms/step
# Epoch 24837/50000
# 11/11 - 0s - loss: 0.9541 - accuracy: 0.6427 - 18ms/epoch - 2ms/step
# Epoch 24838/50000
# 11/11 - 0s - loss: 0.9508 - accuracy: 0.6427 - 17ms/epoch - 2ms/step
# Epoch 24839/50000
# 11/11 - 0s - loss: 0.9424 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24840/50000
# 11/11 - 0s - loss: 0.9322 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24841/50000
# 11/11 - 0s - loss: 0.9313 - accuracy: 0.6524 - 17ms/epoch - 2ms/step
# Epoch 24842/50000
# 11/11 - 0s - loss: 0.9416 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24843/50000
# 11/11 - 0s - loss: 0.9374 - accuracy: 0.6350 - 17ms/epoch - 2ms/step
# Epoch 24844/50000
# 11/11 - 0s - loss: 0.9383 - accuracy: 0.6466 - 18ms/epoch - 2ms/step
# Epoch 24845/50000
# 11/11 - 0s - loss: 0.9610 - accuracy: 0.6311 - 15ms/epoch - 1ms/step
# Epoch 24846/50000
# 11/11 - 0s - loss: 0.9483 - accuracy: 0.6311 - 17ms/epoch - 2ms/step
# Epoch 24847/50000
# 11/11 - 0s - loss: 0.9347 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24848/50000
# 11/11 - 0s - loss: 0.9326 - accuracy: 0.6466 - 14ms/epoch - 1ms/step
# Epoch 24849/50000
# 11/11 - 0s - loss: 0.9287 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 24850/50000
# 11/11 - 0s - loss: 0.9382 - accuracy: 0.6369 - 14ms/epoch - 1ms/step
# Epoch 24851/50000
# 11/11 - 0s - loss: 0.9448 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24852/50000
# 11/11 - 0s - loss: 0.9403 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24853/50000
# 11/11 - 0s - loss: 0.9317 - accuracy: 0.6563 - 16ms/epoch - 1ms/step
# Epoch 24854/50000
# 11/11 - 0s - loss: 0.9378 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24855/50000
# 11/11 - 0s - loss: 0.9394 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24856/50000
# 11/11 - 0s - loss: 0.9470 - accuracy: 0.6350 - 16ms/epoch - 1ms/step
# Epoch 24857/50000
# 11/11 - 0s - loss: 0.9321 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 24858/50000
# 11/11 - 0s - loss: 0.9325 - accuracy: 0.6485 - 17ms/epoch - 2ms/step
# Epoch 24859/50000
# 11/11 - 0s - loss: 0.9422 - accuracy: 0.6408 - 18ms/epoch - 2ms/step
# Epoch 24860/50000
# 11/11 - 0s - loss: 0.9417 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24861/50000
# 11/11 - 0s - loss: 0.9807 - accuracy: 0.6252 - 18ms/epoch - 2ms/step
# Epoch 24862/50000
# 11/11 - 0s - loss: 0.9608 - accuracy: 0.6272 - 14ms/epoch - 1ms/step
# Epoch 24863/50000
# 11/11 - 0s - loss: 0.9431 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 24864/50000
# 11/11 - 0s - loss: 0.9369 - accuracy: 0.6447 - 16ms/epoch - 1ms/step
# Epoch 24865/50000
# 11/11 - 0s - loss: 0.9378 - accuracy: 0.6388 - 15ms/epoch - 1ms/step
# Epoch 24866/50000
# 11/11 - 0s - loss: 0.9374 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24867/50000
# 11/11 - 0s - loss: 0.9324 - accuracy: 0.6485 - 17ms/epoch - 2ms/step
# Epoch 24868/50000
# 11/11 - 0s - loss: 0.9396 - accuracy: 0.6388 - 17ms/epoch - 2ms/step
# Epoch 24869/50000
# 11/11 - 0s - loss: 0.9461 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24870/50000
# 11/11 - 0s - loss: 0.9377 - accuracy: 0.6447 - 17ms/epoch - 2ms/step
# Epoch 24871/50000
# 11/11 - 0s - loss: 0.9309 - accuracy: 0.6505 - 16ms/epoch - 1ms/step
# Epoch 24872/50000
# 11/11 - 0s - loss: 0.9419 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24873/50000
# 11/11 - 0s - loss: 0.9402 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24874/50000
# 11/11 - 0s - loss: 0.9517 - accuracy: 0.6311 - 16ms/epoch - 1ms/step
# Epoch 24875/50000
# 11/11 - 0s - loss: 0.9550 - accuracy: 0.6350 - 16ms/epoch - 1ms/step
# Epoch 24876/50000
# 11/11 - 0s - loss: 0.9352 - accuracy: 0.6524 - 14ms/epoch - 1ms/step
# Epoch 24877/50000
# 11/11 - 0s - loss: 0.9304 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24878/50000
# 11/11 - 0s - loss: 0.9445 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24879/50000
# 11/11 - 0s - loss: 0.9458 - accuracy: 0.6427 - 14ms/epoch - 1ms/step
# Epoch 24880/50000
# 11/11 - 0s - loss: 0.9718 - accuracy: 0.6252 - 15ms/epoch - 1ms/step
# Epoch 24881/50000
# 11/11 - 0s - loss: 0.9754 - accuracy: 0.6214 - 13ms/epoch - 1ms/step
# Epoch 24882/50000
# 11/11 - 0s - loss: 0.9673 - accuracy: 0.6291 - 16ms/epoch - 1ms/step
# Epoch 24883/50000
# 11/11 - 0s - loss: 0.9737 - accuracy: 0.6252 - 15ms/epoch - 1ms/step
# Epoch 24884/50000
# 11/11 - 0s - loss: 0.9604 - accuracy: 0.6388 - 15ms/epoch - 1ms/step
# Epoch 24885/50000
# 11/11 - 0s - loss: 0.9872 - accuracy: 0.6252 - 16ms/epoch - 1ms/step
# Epoch 24886/50000
# 11/11 - 0s - loss: 1.0060 - accuracy: 0.6291 - 17ms/epoch - 2ms/step
# Epoch 24887/50000
# 11/11 - 0s - loss: 0.9834 - accuracy: 0.6136 - 16ms/epoch - 1ms/step
# Epoch 24888/50000
# 11/11 - 0s - loss: 0.9700 - accuracy: 0.6311 - 15ms/epoch - 1ms/step
# Epoch 24889/50000
# 11/11 - 0s - loss: 0.9651 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24890/50000
# 11/11 - 0s - loss: 0.9596 - accuracy: 0.6214 - 15ms/epoch - 1ms/step
# Epoch 24891/50000
# 11/11 - 0s - loss: 0.9458 - accuracy: 0.6427 - 16ms/epoch - 1ms/step
# Epoch 24892/50000
# 11/11 - 0s - loss: 0.9369 - accuracy: 0.6505 - 15ms/epoch - 1ms/step
# Epoch 24893/50000
# 11/11 - 0s - loss: 0.9344 - accuracy: 0.6369 - 15ms/epoch - 1ms/step
# Epoch 24894/50000
# 11/11 - 0s - loss: 0.9415 - accuracy: 0.6350 - 17ms/epoch - 2ms/step
# Epoch 24895/50000
# 11/11 - 0s - loss: 0.9408 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24896/50000
# 11/11 - 0s - loss: 0.9374 - accuracy: 0.6447 - 15ms/epoch - 1ms/step
# Epoch 24897/50000
# 11/11 - 0s - loss: 0.9501 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24898/50000
# 11/11 - 0s - loss: 0.9341 - accuracy: 0.6350 - 16ms/epoch - 1ms/step
# Epoch 24899/50000
# 11/11 - 0s - loss: 0.9340 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24900/50000
# 11/11 - 0s - loss: 0.9410 - accuracy: 0.6388 - 15ms/epoch - 1ms/step
# Epoch 24901/50000
# 11/11 - 0s - loss: 0.9434 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24902/50000
# 11/11 - 0s - loss: 0.9501 - accuracy: 0.6311 - 15ms/epoch - 1ms/step
# Epoch 24903/50000
# 11/11 - 0s - loss: 0.9445 - accuracy: 0.6291 - 15ms/epoch - 1ms/step
# Epoch 24904/50000
# 11/11 - 0s - loss: 0.9682 - accuracy: 0.6291 - 17ms/epoch - 2ms/step
# Epoch 24905/50000
# 11/11 - 0s - loss: 0.9494 - accuracy: 0.6330 - 17ms/epoch - 2ms/step
# Epoch 24906/50000
# 11/11 - 0s - loss: 0.9568 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24907/50000
# 11/11 - 0s - loss: 0.9418 - accuracy: 0.6447 - 16ms/epoch - 1ms/step
# Epoch 24908/50000
# 11/11 - 0s - loss: 0.9747 - accuracy: 0.6214 - 15ms/epoch - 1ms/step
# Epoch 24909/50000
# 11/11 - 0s - loss: 0.9772 - accuracy: 0.6272 - 16ms/epoch - 1ms/step
# Epoch 24910/50000
# 11/11 - 0s - loss: 0.9509 - accuracy: 0.6369 - 15ms/epoch - 1ms/step
# Epoch 24911/50000
# 11/11 - 0s - loss: 0.9384 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24912/50000
# 11/11 - 0s - loss: 0.9291 - accuracy: 0.6466 - 15ms/epoch - 1ms/step
# Epoch 24913/50000
# 11/11 - 0s - loss: 0.9386 - accuracy: 0.6466 - 16ms/epoch - 1ms/step
# Epoch 24914/50000
# 11/11 - 0s - loss: 0.9357 - accuracy: 0.6447 - 16ms/epoch - 1ms/step
# Epoch 24915/50000
# 11/11 - 0s - loss: 0.9325 - accuracy: 0.6485 - 15ms/epoch - 1ms/step
# Epoch 24916/50000
# 11/11 - 0s - loss: 0.9375 - accuracy: 0.6447 - 17ms/epoch - 2ms/step
# Epoch 24917/50000
# 11/11 - 0s - loss: 0.9463 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24918/50000
# 11/11 - 0s - loss: 0.9748 - accuracy: 0.6311 - 16ms/epoch - 1ms/step
# Epoch 24919/50000
# 11/11 - 0s - loss: 0.9852 - accuracy: 0.6233 - 16ms/epoch - 1ms/step
# Epoch 24920/50000
# 11/11 - 0s - loss: 0.9944 - accuracy: 0.6252 - 15ms/epoch - 1ms/step
# Epoch 24921/50000
# 11/11 - 0s - loss: 0.9781 - accuracy: 0.6291 - 14ms/epoch - 1ms/step
# Epoch 24922/50000
# 11/11 - 0s - loss: 0.9530 - accuracy: 0.6350 - 15ms/epoch - 1ms/step
# Epoch 24923/50000
# 11/11 - 0s - loss: 1.0008 - accuracy: 0.6350 - 15ms/epoch - 1ms/step
# Epoch 24924/50000
# 11/11 - 0s - loss: 1.0246 - accuracy: 0.6117 - 15ms/epoch - 1ms/step
# Epoch 24925/50000
# 11/11 - 0s - loss: 0.9668 - accuracy: 0.6369 - 16ms/epoch - 1ms/step
# Epoch 24926/50000
# 11/11 - 0s - loss: 0.9463 - accuracy: 0.6369 - 15ms/epoch - 1ms/step
# Epoch 24927/50000
# 11/11 - 0s - loss: 0.9391 - accuracy: 0.6427 - 16ms/epoch - 1ms/step
# Epoch 24928/50000
# 11/11 - 0s - loss: 0.9428 - accuracy: 0.6369 - 14ms/epoch - 1ms/step
# Epoch 24929/50000
# 11/11 - 0s - loss: 0.9370 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24930/50000
# 11/11 - 0s - loss: 0.9391 - accuracy: 0.6408 - 15ms/epoch - 1ms/step
# Epoch 24931/50000
# 11/11 - 0s - loss: 0.9343 - accuracy: 0.6505 - 14ms/epoch - 1ms/step
# Epoch 24932/50000
# 11/11 - 0s - loss: 0.9382 - accuracy: 0.6408 - 16ms/epoch - 1ms/step
# Epoch 24933/50000
# 11/11 - 0s - loss: 0.9442 - accuracy: 0.6388 - 15ms/epoch - 1ms/step
# Epoch 24934/50000
# 11/11 - 0s - loss: 0.9333 - accuracy: 0.6427 - 15ms/epoch - 1ms/step
# Epoch 24935/50000
# 11/11 - 0s - loss: 0.9331 - accuracy: 0.6466 - 14ms/epoch - 1ms/step
# Epoch 24936/50000
# 11/11 - 0s - loss: 0.9338 - accuracy: 0.6388 - 16ms/epoch - 1ms/step
# Epoch 24937/50000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\JOYCEM~1\AppData\Local\Temp/ipykernel_7792/3054443636.py in <module>
#       1 #fit the model
# ----> 2 model.fit(X, y, epochs=50000, batch_size=50, verbose=2)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
# Out:
# 17/17 [==============================] - 0s 1ms/step - loss: 0.8298 - accuracy: 0.6621
