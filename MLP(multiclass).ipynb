# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
#load the data
df = pd.read_csv('sudo model 1.csv')
df.head()
# Out:
#    Unnamed: 0 Result  Target  PR_Interval  RR_Interval  RS_Interval
# 0           1      j       1     0.000000     0.000000  3699.119444
# 1           2      N       0     0.052778     0.108333     0.230556
# 2           3  (AFIB       1     0.077778     0.300000 -4136.461111
# 3           4      j       1     0.000000     0.000000  3924.050000
# 4           5   (AFL       1     0.061111     0.119444     0.244444

# %%
df = df[["Result", "PR_Interval", "RR_Interval", "RS_Interval"]]
df.head()
# Out:
#   Result  PR_Interval  RR_Interval  RS_Interval
# 0      j     0.000000     0.000000  3699.119444
# 1      N     0.052778     0.108333     0.230556
# 2  (AFIB     0.077778     0.300000 -4136.461111
# 3      j     0.000000     0.000000  3924.050000
# 4   (AFL     0.061111     0.119444     0.244444

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#define the model
#model = Sequential()
#model.add(Dense(3, activation='relu', use_bias=True, kernel_regularizer = keras.regularizers.l1_l2(l1=0.01, l2=0.01),
#               bias_regularizer='l2', activity_regularizer='l2', input_shape=(3,)))
#model.add(Dense(10, activation='relu', use_bias=True, kernel_regularizer = keras.regularizers.l1_l2(l1=0.01, l2=0.01),
 #              bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(50, activation='relu', use_bias=True, kernel_regularizer = keras.regularizers.l1_l2(l1=0.01, l2=0.01),
#               bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(50, activation='relu', use_bias=True, kernel_regularizer = keras.regularizers.l1_l2(l1=0.01, l2=0.01),
#               bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(10, activation='relu', use_bias=True, kernel_regularizer = keras.regularizers.l1_l2(l1=0.01, l2=0.01),
#               bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(5, activation='softmax'))

model = Sequential()
model.add(Dense(3, activation='relu', use_bias=True, input_shape=(3,)))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(5, activation='softmax'))

# %%
#complie the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=100, batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 11/11 - 0s - loss: 64.3201 - accuracy: 0.1689 - 284ms/epoch - 26ms/step
# Epoch 2/100
# 11/11 - 0s - loss: 9.5051 - accuracy: 0.3301 - 8ms/epoch - 727us/step
# Epoch 3/100
# 11/11 - 0s - loss: 1.6059 - accuracy: 0.4388 - 9ms/epoch - 773us/step
# Epoch 4/100
# 11/11 - 0s - loss: 1.5937 - accuracy: 0.3942 - 7ms/epoch - 591us/step
# Epoch 5/100
# 11/11 - 0s - loss: 1.5876 - accuracy: 0.4447 - 8ms/epoch - 682us/step
# Epoch 6/100
# 11/11 - 0s - loss: 1.5812 - accuracy: 0.4466 - 7ms/epoch - 636us/step
# Epoch 7/100
# 11/11 - 0s - loss: 1.5741 - accuracy: 0.4796 - 7ms/epoch - 637us/step
# Epoch 8/100
# 11/11 - 0s - loss: 1.5679 - accuracy: 0.4660 - 7ms/epoch - 591us/step
# Epoch 9/100
# 11/11 - 0s - loss: 1.5603 - accuracy: 0.4563 - 8ms/epoch - 682us/step
# Epoch 10/100
# 11/11 - 0s - loss: 1.5533 - accuracy: 0.4680 - 7ms/epoch - 591us/step
# Epoch 11/100
# 11/11 - 0s - loss: 1.5452 - accuracy: 0.4699 - 7ms/epoch - 637us/step
# Epoch 12/100
# 11/11 - 0s - loss: 1.5377 - accuracy: 0.4621 - 7ms/epoch - 636us/step
# Epoch 13/100
# 11/11 - 0s - loss: 1.5311 - accuracy: 0.4718 - 7ms/epoch - 636us/step
# Epoch 14/100
# 11/11 - 0s - loss: 1.5238 - accuracy: 0.4738 - 7ms/epoch - 636us/step
# Epoch 15/100
# 11/11 - 0s - loss: 1.5169 - accuracy: 0.4660 - 7ms/epoch - 637us/step
# Epoch 16/100
# 11/11 - 0s - loss: 1.5093 - accuracy: 0.4738 - 7ms/epoch - 636us/step
# Epoch 17/100
# 11/11 - 0s - loss: 1.5017 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 18/100
# 11/11 - 0s - loss: 1.4940 - accuracy: 0.4718 - 7ms/epoch - 636us/step
# Epoch 19/100
# 11/11 - 0s - loss: 1.4881 - accuracy: 0.4718 - 7ms/epoch - 637us/step
# Epoch 20/100
# 11/11 - 0s - loss: 1.4804 - accuracy: 0.4757 - 8ms/epoch - 682us/step
# Epoch 21/100
# 11/11 - 0s - loss: 1.4747 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 22/100
# 11/11 - 0s - loss: 1.4701 - accuracy: 0.4738 - 7ms/epoch - 636us/step
# Epoch 23/100
# 11/11 - 0s - loss: 1.4656 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 24/100
# 11/11 - 0s - loss: 1.4614 - accuracy: 0.4757 - 8ms/epoch - 682us/step
# Epoch 25/100
# 11/11 - 0s - loss: 1.4580 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 26/100
# 11/11 - 0s - loss: 1.4540 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 27/100
# 11/11 - 0s - loss: 1.4522 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 28/100
# 11/11 - 0s - loss: 1.4480 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 29/100
# 11/11 - 0s - loss: 1.4457 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 30/100
# 11/11 - 0s - loss: 1.4476 - accuracy: 0.4718 - 7ms/epoch - 637us/step
# Epoch 31/100
# 11/11 - 0s - loss: 1.4371 - accuracy: 0.4796 - 6ms/epoch - 546us/step
# Epoch 32/100
# 11/11 - 0s - loss: 1.4346 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 33/100
# 11/11 - 0s - loss: 1.4315 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 34/100
# 11/11 - 0s - loss: 1.4286 - accuracy: 0.4796 - 7ms/epoch - 637us/step
# Epoch 35/100
# 11/11 - 0s - loss: 1.4264 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 36/100
# 11/11 - 0s - loss: 1.4234 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 37/100
# 11/11 - 0s - loss: 1.4216 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 38/100
# 11/11 - 0s - loss: 1.4183 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 39/100
# 11/11 - 0s - loss: 1.4178 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 40/100
# 11/11 - 0s - loss: 1.4153 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 41/100
# 11/11 - 0s - loss: 1.4118 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 42/100
# 11/11 - 0s - loss: 1.4097 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 43/100
# 11/11 - 0s - loss: 1.4070 - accuracy: 0.4796 - 7ms/epoch - 637us/step
# Epoch 44/100
# 11/11 - 0s - loss: 1.4049 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 45/100
# 11/11 - 0s - loss: 1.4026 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 46/100
# 11/11 - 0s - loss: 1.4009 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 47/100
# 11/11 - 0s - loss: 1.3994 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 48/100
# 11/11 - 0s - loss: 1.3960 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 49/100
# 11/11 - 0s - loss: 1.3955 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 50/100
# 11/11 - 0s - loss: 1.3927 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 51/100
# 11/11 - 0s - loss: 1.3918 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 52/100
# 11/11 - 0s - loss: 1.3893 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 53/100
# 11/11 - 0s - loss: 1.3875 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 54/100
# 11/11 - 0s - loss: 1.3848 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 55/100
# 11/11 - 0s - loss: 1.3829 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 56/100
# 11/11 - 0s - loss: 1.3829 - accuracy: 0.4796 - 7ms/epoch - 637us/step
# Epoch 57/100
# 11/11 - 0s - loss: 1.3799 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 58/100
# 11/11 - 0s - loss: 1.3785 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 59/100
# 11/11 - 0s - loss: 1.3766 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 60/100
# 11/11 - 0s - loss: 1.3752 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 61/100
# 11/11 - 0s - loss: 1.3733 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 62/100
# 11/11 - 0s - loss: 1.3719 - accuracy: 0.4796 - 7ms/epoch - 591us/step
# Epoch 63/100
# 11/11 - 0s - loss: 1.3706 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 64/100
# 11/11 - 0s - loss: 1.3712 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 65/100
# 11/11 - 0s - loss: 1.3679 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 66/100
# 11/11 - 0s - loss: 1.3673 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 67/100
# 11/11 - 0s - loss: 1.3720 - accuracy: 0.4816 - 7ms/epoch - 636us/step
# Epoch 68/100
# 11/11 - 0s - loss: 1.3714 - accuracy: 0.4757 - 8ms/epoch - 682us/step
# Epoch 69/100
# 11/11 - 0s - loss: 1.3645 - accuracy: 0.4757 - 8ms/epoch - 682us/step
# Epoch 70/100
# 11/11 - 0s - loss: 1.3627 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 71/100
# 11/11 - 0s - loss: 1.3614 - accuracy: 0.4757 - 8ms/epoch - 682us/step
# Epoch 72/100
# 11/11 - 0s - loss: 1.3594 - accuracy: 0.4796 - 8ms/epoch - 682us/step
# Epoch 73/100
# 11/11 - 0s - loss: 1.3578 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 74/100
# 11/11 - 0s - loss: 1.3569 - accuracy: 0.4796 - 7ms/epoch - 637us/step
# Epoch 75/100
# 11/11 - 0s - loss: 1.3555 - accuracy: 0.4777 - 7ms/epoch - 591us/step
# Epoch 76/100
# 11/11 - 0s - loss: 1.3546 - accuracy: 0.4796 - 7ms/epoch - 636us/step
# Epoch 77/100
# 11/11 - 0s - loss: 1.3541 - accuracy: 0.4757 - 7ms/epoch - 636us/step
# Epoch 78/100
# 11/11 - 0s - loss: 1.3533 - accuracy: 0.4777 - 8ms/epoch - 682us/step
# Epoch 79/100
# 11/11 - 0s - loss: 1.3535 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 80/100
# 11/11 - 0s - loss: 1.3514 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 81/100
# 11/11 - 0s - loss: 1.3497 - accuracy: 0.4777 - 7ms/epoch - 591us/step
# Epoch 82/100
# 11/11 - 0s - loss: 1.3482 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 83/100
# 11/11 - 0s - loss: 1.3472 - accuracy: 0.4777 - 7ms/epoch - 591us/step
# Epoch 84/100
# 11/11 - 0s - loss: 1.3465 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 85/100
# 11/11 - 0s - loss: 1.3457 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 86/100
# 11/11 - 0s - loss: 1.3445 - accuracy: 0.4777 - 8ms/epoch - 682us/step
# Epoch 87/100
# 11/11 - 0s - loss: 1.3448 - accuracy: 0.4777 - 8ms/epoch - 682us/step
# Epoch 88/100
# 11/11 - 0s - loss: 1.3461 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 89/100
# 11/11 - 0s - loss: 1.3424 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 90/100
# 11/11 - 0s - loss: 1.3421 - accuracy: 0.4777 - 7ms/epoch - 637us/step
# Epoch 91/100
# 11/11 - 0s - loss: 1.3436 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 92/100
# 11/11 - 0s - loss: 1.3400 - accuracy: 0.4777 - 7ms/epoch - 637us/step
# Epoch 93/100
# 11/11 - 0s - loss: 1.3390 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 94/100
# 11/11 - 0s - loss: 1.3374 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 95/100
# 11/11 - 0s - loss: 1.3358 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 96/100
# 11/11 - 0s - loss: 1.3343 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 97/100
# 11/11 - 0s - loss: 1.3411 - accuracy: 0.4777 - 7ms/epoch - 636us/step
# Epoch 98/100
# 11/11 - 0s - loss: 1.3341 - accuracy: 0.4777 - 7ms/epoch - 591us/step
# Epoch 99/100
# 11/11 - 0s - loss: 1.3338 - accuracy: 0.4777 - 8ms/epoch - 682us/step
# Epoch 100/100
# 11/11 - 0s - loss: 1.3327 - accuracy: 0.4777 - 7ms/epoch - 591us/step

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
# Out:
# 17/17 [==============================] - 0s 531us/step - loss: 1.3304 - accuracy: 0.4777
