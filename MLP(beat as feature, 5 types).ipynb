# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import confusion_matrix

# %%
#load the data
df = pd.read_csv('Model 1.csv')
df.head()
# Out:
#   Result    0    3    6    9    12    15    18    21    24  ...   258   261  \
# 0      N  967  967  966  978   970   970   965   971   962  ...   966   967
# 1      N  987  981  984  980   981   980   979   981   981  ...  1004   995
# 2      N  969  972  986  991  1004  1006  1013  1011  1014  ...  1015  1012
# 3      N  954  960  951  951   951   952   951   949   946  ...   969   974
# 4      Q  986  988  985  985   984   987   983   984   983  ...   973   983
#
#     264   267   270   273   276   279   282   285
# 0   961   961   969   961   966   964   960   958
# 1   986   967   969   961   957   957   955   951
# 2  1015  1008  1007  1001  1006  1001  1009  1007
# 3   973   981   974   977   969   977   975   976
# 4   983   990   994   997   996  1001   996   998
#
# [5 rows x 97 columns]

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#define the model
model = Sequential()
model.add(Dense(3, activation='relu', use_bias=True, input_shape=(96,)))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(40, activation='relu', use_bias=True))
model.add(Dense(40, activation='relu', use_bias=True))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(5, activation='softmax'))

# %%
#complie
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['Accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=200, batch_size=100, verbose=2)
# Out:
# Epoch 1/200
# 320/320 - 3s - loss: 8.6382 - Accuracy: 0.4007 - 3s/epoch - 9ms/step
# Epoch 2/200
# 320/320 - 1s - loss: 1.3637 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 3/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 4/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 5/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 6/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 7/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 8/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 9/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 10/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 11/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 808ms/epoch - 3ms/step
# Epoch 12/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 13/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 14/200
# 320/320 - 1s - loss: 1.3545 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 15/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 16/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 17/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 18/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 19/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 20/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 21/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 22/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 23/200
# 320/320 - 1s - loss: 1.3545 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 24/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 25/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 948ms/epoch - 3ms/step
# Epoch 26/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 855ms/epoch - 3ms/step
# Epoch 27/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 763ms/epoch - 2ms/step
# Epoch 28/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 929ms/epoch - 3ms/step
# Epoch 29/200
# 320/320 - 2s - loss: 1.3548 - Accuracy: 0.4093 - 2s/epoch - 5ms/step
# Epoch 30/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 31/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 32/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 33/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 1s/epoch - 5ms/step
# Epoch 34/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 35/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 36/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 37/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 38/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 39/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 40/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 41/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 42/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 43/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 44/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 45/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 46/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 47/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 48/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 49/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 50/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 51/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 52/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 53/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 54/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 55/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 56/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 57/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 58/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 59/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 60/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 61/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 62/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 63/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 64/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 65/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 66/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 67/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 68/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 69/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 70/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 71/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 72/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 73/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 74/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 75/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 76/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 77/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 78/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 79/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 80/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 81/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 82/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 83/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 84/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 85/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 86/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 87/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 88/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 762ms/epoch - 2ms/step
# Epoch 89/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 799ms/epoch - 2ms/step
# Epoch 90/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 819ms/epoch - 3ms/step
# Epoch 91/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 750ms/epoch - 2ms/step
# Epoch 92/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 93/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 94/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 95/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 96/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 97/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 98/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 99/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 100/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 101/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 102/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 103/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 776ms/epoch - 2ms/step
# Epoch 104/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 885ms/epoch - 3ms/step
# Epoch 105/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 983ms/epoch - 3ms/step
# Epoch 106/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 985ms/epoch - 3ms/step
# Epoch 107/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 108/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 905ms/epoch - 3ms/step
# Epoch 109/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 971ms/epoch - 3ms/step
# Epoch 110/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 111/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 112/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 785ms/epoch - 2ms/step
# Epoch 113/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 114/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 5ms/step
# Epoch 115/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 116/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 117/200
# 320/320 - 2s - loss: 1.3548 - Accuracy: 0.4093 - 2s/epoch - 5ms/step
# Epoch 118/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 119/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 5ms/step
# Epoch 120/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 121/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 122/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 801ms/epoch - 3ms/step
# Epoch 123/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 857ms/epoch - 3ms/step
# Epoch 124/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 987ms/epoch - 3ms/step
# Epoch 125/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 126/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 127/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 128/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 819ms/epoch - 3ms/step
# Epoch 129/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 921ms/epoch - 3ms/step
# Epoch 130/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 710ms/epoch - 2ms/step
# Epoch 131/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 800ms/epoch - 2ms/step
# Epoch 132/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 874ms/epoch - 3ms/step
# Epoch 133/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 134/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 135/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 736ms/epoch - 2ms/step
# Epoch 136/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 767ms/epoch - 2ms/step
# Epoch 137/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 138/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 139/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 140/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 141/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 142/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 143/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 144/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 145/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 966ms/epoch - 3ms/step
# Epoch 146/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 147/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 841ms/epoch - 3ms/step
# Epoch 148/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 965ms/epoch - 3ms/step
# Epoch 149/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 150/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 876ms/epoch - 3ms/step
# Epoch 151/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 866ms/epoch - 3ms/step
# Epoch 152/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 153/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 154/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 810ms/epoch - 3ms/step
# Epoch 155/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 772ms/epoch - 2ms/step
# Epoch 156/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 754ms/epoch - 2ms/step
# Epoch 157/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 786ms/epoch - 2ms/step
# Epoch 158/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 159/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 160/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 161/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 162/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 163/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 164/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 165/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 166/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 167/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 168/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 788ms/epoch - 2ms/step
# Epoch 169/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 718ms/epoch - 2ms/step
# Epoch 170/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 741ms/epoch - 2ms/step
# Epoch 171/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 731ms/epoch - 2ms/step
# Epoch 172/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 728ms/epoch - 2ms/step
# Epoch 173/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 727ms/epoch - 2ms/step
# Epoch 174/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 733ms/epoch - 2ms/step
# Epoch 175/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 724ms/epoch - 2ms/step
# Epoch 176/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 759ms/epoch - 2ms/step
# Epoch 177/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 726ms/epoch - 2ms/step
# Epoch 178/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 735ms/epoch - 2ms/step
# Epoch 179/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 180/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 181/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 182/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 183/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 184/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 185/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 186/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 187/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 188/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 189/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 190/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 191/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 192/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 193/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 194/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 195/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 196/200
# 320/320 - 942s - loss: 1.3546 - Accuracy: 0.4093 - 942s/epoch - 3s/step
# Epoch 197/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 1s/epoch - 4ms/step
# Epoch 198/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 199/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 1s/epoch - 3ms/step
# Epoch 200/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 987ms/epoch - 3ms/step

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
# Out:
# 998/998 [==============================] - 3s 3ms/step - loss: 1.3548 - Accuracy: 0.4093

# %%
prediction = model.predict(X_test)
print(prediction)
# Out:
# [[0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]
#  [0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]
#  [0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]
#  ...
#  [0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]
#  [0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]
#  [0.02427989 0.42147782 0.24454117 0.08555445 0.22414666]]

# %%
confusion_matrix(y_test, prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\JOYCEM~1\AppData\Local\Temp/ipykernel_2060/772330386.py in <module>
# ----> 1 confusion_matrix(y_test, prediction)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     297
#     298     """
# --> 299     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     300     if y_type not in ("binary", "multiclass"):
#     301         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous-multioutput targets
