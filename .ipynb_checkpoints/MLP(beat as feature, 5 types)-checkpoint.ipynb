# %%
#from numpy.random import seed
#seed(1)
#from tensorflow import random
#random.set_seed(2)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import KFold
from sklearn.metrics import ConfusionMatrixDisplay

# %%
#load the data
df = pd.read_csv('Model 1.csv')
df.head()
# Out:
#   Result    0    3    6    9    12    15    18    21    24  ...   258   261  \
# 0      N  967  967  966  978   970   970   965   971   962  ...   966   967
# 1      N  987  981  984  980   981   980   979   981   981  ...  1004   995
# 2      N  969  972  986  991  1004  1006  1013  1011  1014  ...  1015  1012
# 3      N  954  960  951  951   951   952   951   949   946  ...   969   974
# 4      Q  986  988  985  985   984   987   983   984   983  ...   973   983
#
#     264   267   270   273   276   279   282   285
# 0   961   961   969   961   966   964   960   958
# 1   986   967   969   961   957   957   955   951
# 2  1015  1008  1007  1001  1006  1001  1009  1007
# 3   973   981   974   977   969   977   975   976
# 4   983   990   994   997   996  1001   996   998
#
# [5 rows x 97 columns]

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#k fold cross validation
#kf = KFold(n_splits=10)
#for train_index, test_index in kf.split(X):
#    X_train, X_test = X[train_index], X[test_index]
#    y_train, y_test = y[train_index], y[test_index]

# %%
#define the model
model = Sequential()
model.add(Dense(48, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
               bias_regularizer='l2', activity_regularizer='l2', input_shape=(96,)))
model.add(Dense(24, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
               bias_regularizer='l2', activity_regularizer='l2'))


model.add(Dense(12, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
               bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(16, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
#               bias_regularizer='l2', activity_regularizer='l2'))

#model.add(Dense(8, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
#               bias_regularizer='l2', activity_regularizer='l2'))
#model.add(Dense(16, activation='relu', use_bias=False,kernel_regularizer=regularizers.l2(0.0001),
#               bias_regularizer='l2', activity_regularizer='l2'))

model.add(Dense(5, activation='softmax'))

# %%
#complie
opt = optimizers.SGD(learning_rate=0.01, momentum = 0.8)
model.compile(opt, loss='sparse_categorical_crossentropy', metrics=['Accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=200, batch_size=100, verbose=2)
# Out:
# Epoch 1/200
# 320/320 - 0s - loss: 520568482523997095930986758144.0000 - Accuracy: 0.4071 - 485ms/epoch - 2ms/step
# Epoch 2/200
# 320/320 - 0s - loss: 532684072635651868819760087040.0000 - Accuracy: 0.4093 - 167ms/epoch - 520us/step
# Epoch 3/200
# 320/320 - 0s - loss: 529285139914873475937911963648.0000 - Accuracy: 0.4093 - 163ms/epoch - 508us/step
# Epoch 4/200
# 320/320 - 0s - loss: 525908950111076583267413000192.0000 - Accuracy: 0.4093 - 165ms/epoch - 514us/step
# Epoch 5/200
# 320/320 - 0s - loss: 522553727614463631821662846976.0000 - Accuracy: 0.4093 - 159ms/epoch - 497us/step
# Epoch 6/200
# 320/320 - 0s - loss: 519219661319693936386470051840.0000 - Accuracy: 0.4093 - 161ms/epoch - 503us/step
# Epoch 7/200
# 320/320 - 0s - loss: 515906826784631222876158033920.0000 - Accuracy: 0.4093 - 168ms/epoch - 524us/step
# Epoch 8/200
# 320/320 - 0s - loss: 512616055145776476348284403712.0000 - Accuracy: 0.4093 - 165ms/epoch - 514us/step
# Epoch 9/200
# 320/320 - 0s - loss: 509345986361582630345027616768.0000 - Accuracy: 0.4093 - 161ms/epoch - 503us/step
# Epoch 10/200
# 320/320 - 0s - loss: 506096431537390370080579125248.0000 - Accuracy: 0.4093 - 160ms/epoch - 499us/step
# Epoch 11/200
# 320/320 - 0s - loss: 502866597315630573454543028224.0000 - Accuracy: 0.4093 - 160ms/epoch - 500us/step
# Epoch 12/200
# 320/320 - 0s - loss: 499659506010852277039856091136.0000 - Accuracy: 0.4093 - 163ms/epoch - 508us/step
# Epoch
0000 - Accuracy: 0.4093 - 164ms/epoch - 513us/step
# Epoch 130/200
# 320/320 - 0s - loss: 234792038072035355087243051008.0000 - Accuracy: 0.4093 - 170ms/epoch - 531us/step
# Epoch 131/200
# 320/320 - 0s - loss: 233294613439249253547141758976.0000 - Accuracy: 0.4093 - 169ms/epoch - 528us/step
# Epoch 132/200
# 320/320 - 0s - loss: 231806085744916878418623070208.0000 - Accuracy: 0.4093 - 166ms/epoch - 517us/step
# Epoch 133/200
# 320/320 - 0s - loss: 230326719441561270401818951680.0000 - Accuracy: 0.4093 - 171ms/epoch - 533us/step
# Epoch 134/200
# 320/320 - 0s - loss: 228857855681263564475970093056.0000 - Accuracy: 0.4093 - 162ms/epoch - 505us/step
# Epoch 135/200
# 320/320 - 0s - loss: 227397945527817379397446402048.0000 - Accuracy: 0.4093 - 172ms/epoch - 538us/step
# Epoch 136/200
# 320/320 - 0s - loss: 225946327849915113415917961216.0000 - Accuracy: 0.4093 - 171ms/epoch - 534us/step
# Epoch 137/200
# 320/320 - 0s - loss: 224505401609730064311153328128.0000 - Accuracy: 0.4093 - 174ms/epoch - 544us/step
# Epoch 138/200
# 320/320 - 0s - loss: 223073202302805358310743605248.0000 - Accuracy: 0.4093 - 168ms/epoch - 524us/step
# Epoch 139/200
# 320/320 - 0s - loss: 221649956602732173157659049984.0000 - Accuracy: 0.4093 - 166ms/epoch - 519us/step
# Epoch 140/200
# 320/320 - 0s - loss: 220235305609657810758863421440.0000 - Accuracy: 0.4093 - 165ms/epoch - 516us/step
# Epoch 141/200
# 320/320 - 0s - loss: 218830930486050172708052795392.0000 - Accuracy: 0.4093 - 171ms/epoch - 533us/step
# Epoch 142/200
# 320/320 - 0s - loss: 217434923395850179668560838656.0000 - Accuracy: 0.4093 - 175ms/epoch - 547us/step
# Epoch 143/200
# 320/320 - 0s - loss: 216048266591286268526592000000.0000 - Accuracy: 0.4093 - 182ms/epoch - 567us/step
# Epoch 144/200
# 320/320 - 1s - loss: 214668825562708182202509688832.0000 - Accuracy: 0.4093 - 784ms/epoch - 2ms/step
# Epoch 145/200
# 320/320 - 1s - loss: 213299754850926477619316654080.0000 - Accuracy: 0.4093 - 624ms/epoch - 2ms/step
# Epoch 146/200
# 320/320 - 0s - loss: 211939392182939184661897674752.0000 - Accuracy: 0.4093 - 398ms/epoch - 1ms/step
# Epoch 147/200
# 320/320 - 0s - loss: 210587151985302427494246252544.0000 - Accuracy: 0.4093 - 228ms/epoch - 711us/step
# Epoch 148/200
# 320/320 - 0s - loss: 209242977589618411680619823104.0000 - Accuracy: 0.4093 - 239ms/epoch - 745us/step
# Epoch 149/200
# 320/320 - 0s - loss: 207908474600491312900391043072.0000 - Accuracy: 0.4093 - 277ms/epoch - 866us/step
# Epoch 150/200
# 320/320 - 0s - loss: 206582811881420146096002301952.0000 - Accuracy: 0.4093 - 256ms/epoch - 799us/step
# Epoch 151/200
# 320/320 - 0s - loss: 205263722696493133837751025664.0000 - Accuracy: 0.4093 - 205ms/epoch - 641us/step
# Epoch 152/200
# 320/320 - 0s - loss: 203954267139191175655735689216.0000 - Accuracy: 0.4093 - 199ms/epoch - 622us/step
# Epoch 153/200
# 320/320 - 0s - loss: 202653802967672601278207229952.0000 - Accuracy: 0.4093 - 183ms/epoch - 570us/step
# Epoch 154/200
# 320/320 - 0s - loss: 201360800135196960940116410368.0000 - Accuracy: 0.4093 - 191ms/epoch - 597us/step
# Epoch 155/200
# 320/320 - 0s - loss: 200075315310162049077205794816.0000 - Accuracy: 0.4093 - 176ms/epoch - 550us/step
# Epoch 156/200
# 320/320 - 0s - loss: 198799388554888465376207699968.0000 - Accuracy: 0.4093 - 163ms/epoch - 508us/step
# Epoch
0000 - Accuracy: 0.4093 - 163ms/epoch - 508us/step
# Epoch 187/200
# 320/320 - 0s - loss: 163022872306929553587312787456.0000 - Accuracy: 0.4093 - 173ms/epoch - 541us/step
# Epoch 188/200
# 320/320 - 0s - loss: 161982874981140137361190944768.0000 - Accuracy: 0.4093 - 166ms/epoch - 517us/step
# Epoch 189/200
# 320/320 - 0s - loss: 160949526747358601595529986048.0000 - Accuracy: 0.4093 - 165ms/epoch - 516us/step
# Epoch 190/200
# 320/320 - 0s - loss: 159922619821459700025940508672.0000 - Accuracy: 0.4093 - 164ms/epoch - 511us/step
# Epoch 191/200
# 320/320 - 0s - loss: 158902135313977501173841657856.0000 - Accuracy: 0.4093 - 163ms/epoch - 509us/step
# Epoch 192/200
# 320/320 - 0s - loss: 157888838248282229921758052352.0000 - Accuracy: 0.4093 - 170ms/epoch - 531us/step
# Epoch 193/200
# 320/320 - 0s - loss: 156881075796104881893864898560.0000 - Accuracy: 0.4093 - 167ms/epoch - 520us/step
# Epoch 194/200
# 320/320 - 0s - loss: 155880340225254043898049724416.0000 - Accuracy: 0.4093 - 163ms/epoch - 508us/step
# Epoch 195/200
# 320/320 - 0s - loss: 154885403720444169826556968960.0000 - Accuracy: 0.4093 - 166ms/epoch - 517us/step
# Epoch 196/200
# 320/320 - 0s - loss: 153898023002006887187406127104.0000 - Accuracy: 0.4093 - 165ms/epoch - 514us/step
# Epoch 197/200
# 320/320 - 0s - loss: 152915893555098555593732915200.0000 - Accuracy: 0.4093 - 165ms/epoch - 516us/step
# Epoch 198/200
# 320/320 - 0s - loss: 151940214860805823935421612032.0000 - Accuracy: 0.4093 - 160ms/epoch - 499us/step
# Epoch 199/200
# 320/320 - 0s - loss: 150971336374248424566218031104.0000 - Accuracy: 0.4093 - 164ms/epoch - 511us/step
# Epoch 200/200
# 320/320 - 0s - loss: 150007737493418873460363362304.0000 - Accuracy: 0.4093 - 171ms/epoch - 533us/step

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
# Out:
# 998/998 [==============================] - 1s 490us/step - loss: 149527123366991298188384665600.0000 - Accuracy: 0.4093

# %%
prediction = model.predict(X_test)
print(prediction)
# Out:
# [[0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]
#  [0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]
#  [0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]
#  ...
#  [0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]
#  [0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]
#  [0.02524521 0.40476716 0.24966027 0.08730972 0.23301767]]

# %%
#this is stupid
length = len(y_test)
Y_test = pd.DataFrame(y_test)
zero=[]
one=[]
two=[]
three=[]
four=[]
for i in range(length):
    if int(Y_test.iloc[i])==0:
        zero.append(1)
        one.append(0)
        two.append(0)
        three.append(0)
        four.append(0)
    elif int(Y_test.iloc[i])==1:
        zero.append(0)
        one.append(1)
        two.append(0)
        three.append(0)
        four.append(0)
    elif int(Y_test.iloc[i])==2:
        zero.append(0)
        one.append(0)
        two.append(1)
        three.append(0)
        four.append(0)
    elif int(Y_test.iloc[i])==3:
        zero.append(0)
        one.append(0)
        two.append(0)
        three.append(1)
        four.append(0)
    elif int(Y_test.iloc[i])==4:
        zero.append(0)
        one.append(0)
        two.append(0)
        three.append(0)
        four.append(1)
        
Y_test[0]=zero
Y_test[1]=one
Y_test[2]=two
Y_test[3]=three
Y_test[4]=four
roc_auc_score(Y_test.to_numpy(), prediction)#how accurate the accuracy is
# Out:
# 0.5

# %%
y_pred=np.argmax(prediction, axis=1)
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[   0  157    0    0    0]
#  [   0 2623    0    0    0]
#  [   0 1618    0    0    0]
#  [   0  554    0    0    0]
#  [   0 1433    0    0    0]]
