# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
#load the data
df = pd.read_csv('Model 1.csv')
df.head()
# Out:
#   Result    0    3    6    9    12    15    18    21    24  ...   258   261  \
# 0      N  967  967  966  978   970   970   965   971   962  ...   966   967
# 1      N  987  981  984  980   981   980   979   981   981  ...  1004   995
# 2      N  969  972  986  991  1004  1006  1013  1011  1014  ...  1015  1012
# 3      N  954  960  951  951   951   952   951   949   946  ...   969   974
# 4      Q  986  988  985  985   984   987   983   984   983  ...   973   983
#
#     264   267   270   273   276   279   282   285
# 0   961   961   969   961   966   964   960   958
# 1   986   967   969   961   957   957   955   951
# 2  1015  1008  1007  1001  1006  1001  1009  1007
# 3   973   981   974   977   969   977   975   976
# 4   983   990   994   997   996  1001   996   998
#
# [5 rows x 97 columns]

# %%
#seperate input and output
X,y = df.iloc[:, 1:], df.iloc[:, 0]
#m\change outputs into numbers
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

#seperate training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#define the model
model = Sequential()
model.add(Dense(3, activation='relu', use_bias=True, input_shape=(96,)))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(50, activation='relu', use_bias=True))
model.add(Dense(10, activation='relu', use_bias=True))
model.add(Dense(6, activation='softmax'))

# %%
#complie
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['Accuracy'])

# %%
#fit the model
model.fit(X, y, epochs=200, batch_size=100, verbose=2)
# Out:
# Epoch 1/200
# 320/320 - 1s - loss: 2.3847 - Accuracy: 0.3117 - 945ms/epoch - 3ms/step
# Epoch 2/200
# 320/320 - 1s - loss: 1.3881 - Accuracy: 0.4100 - 513ms/epoch - 2ms/step
# Epoch 3/200
# 320/320 - 1s - loss: 1.3562 - Accuracy: 0.4097 - 504ms/epoch - 2ms/step
# Epoch 4/200
# 320/320 - 1s - loss: 1.3568 - Accuracy: 0.4120 - 510ms/epoch - 2ms/step
# Epoch 5/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 509ms/epoch - 2ms/step
# Epoch 6/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 519ms/epoch - 2ms/step
# Epoch 7/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 514ms/epoch - 2ms/step
# Epoch 8/200
# 320/320 - 1s - loss: 1.3554 - Accuracy: 0.4093 - 554ms/epoch - 2ms/step
# Epoch 9/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 501ms/epoch - 2ms/step
# Epoch 10/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 502ms/epoch - 2ms/step
# Epoch 11/200
# 320/320 - 1s - loss: 1.3554 - Accuracy: 0.4093 - 519ms/epoch - 2ms/step
# Epoch 12/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 523ms/epoch - 2ms/step
# Epoch 13/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 505ms/epoch - 2ms/step
# Epoch 14/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 502ms/epoch - 2ms/step
# Epoch 15/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 540ms/epoch - 2ms/step
# Epoch 16/200
# 320/320 - 1s - loss: 1.3554 - Accuracy: 0.4093 - 512ms/epoch - 2ms/step
# Epoch 17/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 509ms/epoch - 2ms/step
# Epoch 18/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 19/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 504ms/epoch - 2ms/step
# Epoch 20/200
# 320/320 - 1s - loss: 1.3557 - Accuracy: 0.4093 - 502ms/epoch - 2ms/step
# Epoch 21/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 22/200
# 320/320 - 0s - loss: 1.3551 - Accuracy: 0.4093 - 495ms/epoch - 2ms/step
# Epoch 23/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 505ms/epoch - 2ms/step
# Epoch 24/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 522ms/epoch - 2ms/step
# Epoch 25/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 501ms/epoch - 2ms/step
# Epoch 26/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 509ms/epoch - 2ms/step
# Epoch 27/200
# 320/320 - 0s - loss: 1.3553 - Accuracy: 0.4093 - 495ms/epoch - 2ms/step
# Epoch 28/200
# 320/320 - 0s - loss: 1.3554 - Accuracy: 0.4093 - 493ms/epoch - 2ms/step
# Epoch 29/200
# 320/320 - 0s - loss: 1.3552 - Accuracy: 0.4093 - 500ms/epoch - 2ms/step
# Epoch 30/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 547ms/epoch - 2ms/step
# Epoch 31/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 554ms/epoch - 2ms/step
# Epoch 32/200
# 320/320 - 1s - loss: 1.3552 - Accuracy: 0.4093 - 550ms/epoch - 2ms/step
# Epoch 33/200
# 320/320 - 0s - loss: 1.3549 - Accuracy: 0.4093 - 488ms/epoch - 2ms/step
# Epoch 34/200
# 320/320 - 1s - loss: 1.3554 - Accuracy: 0.4093 - 500ms/epoch - 2ms/step
# Epoch 35/200
# 320/320 - 0s - loss: 1.3554 - Accuracy: 0.4093 - 491ms/epoch - 2ms/step
# Epoch 36/200
# 320/320 - 1s - loss: 1.3553 - Accuracy: 0.4093 - 564ms/epoch - 2ms/step
# Epoch 37/200
# 320/320 - 0s - loss: 1.3551 - Accuracy: 0.4093 - 499ms/epoch - 2ms/step
# Epoch 38/200
# 320/320 - 0s - loss: 1.3553 - Accuracy: 0.4093 - 498ms/epoch - 2ms/step
# Epoch 39/200
# 320/320 - 0s - loss: 1.3551 - Accuracy: 0.4093 - 494ms/epoch - 2ms/step
# Epoch 40/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 553ms/epoch - 2ms/step
# Epoch 41/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 518ms/epoch - 2ms/step
# Epoch 42/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 506ms/epoch - 2ms/step
# Epoch 43/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 720ms/epoch - 2ms/step
# Epoch 44/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 614ms/epoch - 2ms/step
# Epoch 45/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 554ms/epoch - 2ms/step
# Epoch 46/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 517ms/epoch - 2ms/step
# Epoch 47/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 523ms/epoch - 2ms/step
# Epoch 48/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 509ms/epoch - 2ms/step
# Epoch 49/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 599ms/epoch - 2ms/step
# Epoch 50/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 528ms/epoch - 2ms/step
# Epoch 51/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 510ms/epoch - 2ms/step
# Epoch 52/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 516ms/epoch - 2ms/step
# Epoch 53/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 54/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 55/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 504ms/epoch - 2ms/step
# Epoch 56/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 501ms/epoch - 2ms/step
# Epoch 57/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 525ms/epoch - 2ms/step
# Epoch 58/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 553ms/epoch - 2ms/step
# Epoch 59/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 581ms/epoch - 2ms/step
# Epoch 60/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 544ms/epoch - 2ms/step
# Epoch 61/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 544ms/epoch - 2ms/step
# Epoch 62/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 529ms/epoch - 2ms/step
# Epoch 63/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 549ms/epoch - 2ms/step
# Epoch 64/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 563ms/epoch - 2ms/step
# Epoch 65/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 541ms/epoch - 2ms/step
# Epoch 66/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 549ms/epoch - 2ms/step
# Epoch 67/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 509ms/epoch - 2ms/step
# Epoch 68/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 540ms/epoch - 2ms/step
# Epoch 69/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 537ms/epoch - 2ms/step
# Epoch 70/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 512ms/epoch - 2ms/step
# Epoch 71/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 540ms/epoch - 2ms/step
# Epoch 72/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 517ms/epoch - 2ms/step
# Epoch 73/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 533ms/epoch - 2ms/step
# Epoch 74/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 515ms/epoch - 2ms/step
# Epoch 75/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 512ms/epoch - 2ms/step
# Epoch 76/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 518ms/epoch - 2ms/step
# Epoch 77/200
# 320/320 - 1s - loss: 1.3551 - Accuracy: 0.4093 - 598ms/epoch - 2ms/step
# Epoch 78/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 557ms/epoch - 2ms/step
# Epoch 79/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 513ms/epoch - 2ms/step
# Epoch 80/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 518ms/epoch - 2ms/step
# Epoch 81/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 522ms/epoch - 2ms/step
# Epoch 82/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 514ms/epoch - 2ms/step
# Epoch 83/200
# 320/320 - 0s - loss: 1.3549 - Accuracy: 0.4093 - 492ms/epoch - 2ms/step
# Epoch 84/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 501ms/epoch - 2ms/step
# Epoch 85/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 508ms/epoch - 2ms/step
# Epoch 86/200
# 320/320 - 0s - loss: 1.3548 - Accuracy: 0.4093 - 495ms/epoch - 2ms/step
# Epoch 87/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 518ms/epoch - 2ms/step
# Epoch 88/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 508ms/epoch - 2ms/step
# Epoch 89/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 503ms/epoch - 2ms/step
# Epoch 90/200
# 320/320 - 1s - loss: 1.3550 - Accuracy: 0.4093 - 511ms/epoch - 2ms/step
# Epoch 91/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 506ms/epoch - 2ms/step
# Epoch 92/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 503ms/epoch - 2ms/step
# Epoch 93/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 514ms/epoch - 2ms/step
# Epoch 94/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 506ms/epoch - 2ms/step
# Epoch 95/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 96/200
# 320/320 - 0s - loss: 1.3548 - Accuracy: 0.4093 - 500ms/epoch - 2ms/step
# Epoch 97/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 507ms/epoch - 2ms/step
# Epoch 98/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 541ms/epoch - 2ms/step
# Epoch 99/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 554ms/epoch - 2ms/step
# Epoch 100/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 561ms/epoch - 2ms/step
# Epoch 101/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 514ms/epoch - 2ms/step
# Epoch 102/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 553ms/epoch - 2ms/step
# Epoch 103/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 520ms/epoch - 2ms/step
# Epoch 104/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 514ms/epoch - 2ms/step
# Epoch 105/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 540ms/epoch - 2ms/step
# Epoch 106/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 533ms/epoch - 2ms/step
# Epoch 107/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 544ms/epoch - 2ms/step
# Epoch 108/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 516ms/epoch - 2ms/step
# Epoch 109/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 553ms/epoch - 2ms/step
# Epoch 110/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 546ms/epoch - 2ms/step
# Epoch 111/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 515ms/epoch - 2ms/step
# Epoch 112/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 616ms/epoch - 2ms/step
# Epoch 113/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 559ms/epoch - 2ms/step
# Epoch 114/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 518ms/epoch - 2ms/step
# Epoch 115/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 530ms/epoch - 2ms/step
# Epoch 116/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 543ms/epoch - 2ms/step
# Epoch 117/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 530ms/epoch - 2ms/step
# Epoch 118/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 574ms/epoch - 2ms/step
# Epoch 119/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 565ms/epoch - 2ms/step
# Epoch 120/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 522ms/epoch - 2ms/step
# Epoch 121/200
# 320/320 - 1s - loss: 1.3546 - Accuracy: 0.4093 - 540ms/epoch - 2ms/step
# Epoch 122/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 544ms/epoch - 2ms/step
# Epoch 123/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 589ms/epoch - 2ms/step
# Epoch 124/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 511ms/epoch - 2ms/step
# Epoch 125/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 551ms/epoch - 2ms/step
# Epoch 126/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 598ms/epoch - 2ms/step
# Epoch 127/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 650ms/epoch - 2ms/step
# Epoch 128/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 728ms/epoch - 2ms/step
# Epoch 129/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 523ms/epoch - 2ms/step
# Epoch 130/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 535ms/epoch - 2ms/step
# Epoch 131/200
# 320/320 - 1s - loss: 1.3547 - Accuracy: 0.4093 - 535ms/epoch - 2ms/step
# Epoch 132/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 750ms/epoch - 2ms/step
# Epoch 133/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 526ms/epoch - 2ms/step
# Epoch 134/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 543ms/epoch - 2ms/step
# Epoch 135/200
# 320/320 - 1s - loss: 1.3548 - Accuracy: 0.4093 - 533ms/epoch - 2ms/step
# Epoch 136/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 539ms/epoch - 2ms/step
# Epoch 137/200
# 320/320 - 1s - loss: 1.3549 - Accuracy: 0.4093 - 536ms/epoch - 2ms/step
# Epoch 138/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\JOYCEM~1\AppData\Local\Temp/ipykernel_24224/2025774104.py in <module>
#       1 #fit the model
# ----> 2 model.fit(X, y, epochs=200, batch_size=100, verbose=2)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
# -> 1208           for step in data_handler.steps():
#    1209             with tf.profiler.experimental.Trace(
#    1210                 'train',
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in steps(self)
#    1248       if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1249         break
# -> 1250       original_spe = self._steps_per_execution.numpy().item()
#    1251       can_run_full_execution = (
#    1252           original_spe == 1 or
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in numpy(self)
#     643   def numpy(self):
#     644     if context.executing_eagerly():
# --> 645       return self.read_value().numpy()
#     646     raise NotImplementedError(
#     647         "numpy() is only available when eager execution is enabled.")
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in read_value(self)
#     721     # Return an identity so it can get placed on whatever device the context
#     722     # specifies instead of the device where the variable is.
# --> 723     return array_ops.identity(value)
#     724
#     725   def sparse_read(self, indices, name=None):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in identity(input, name)
#     288     # variables. Variables have correct handle data when graph building.
#     289     input = ops.convert_to_tensor(input)
# --> 290   ret = gen_array_ops.identity(input, name=name)
#     291   # Propagate handle data for happier shape inference for resource variables.
#     292   if hasattr(input, "_handle_data"):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in identity(input, name)
#    4061   if tld.is_eager:
#    4062     try:
# -> 4063       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    4064         _ctx, "Identity", name, input)
#    4065       return _result
#
# KeyboardInterrupt:

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=True)
