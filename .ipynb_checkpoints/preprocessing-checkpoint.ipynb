# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mlbeats # python file that include usful functions
from biosppy.signals import ecg
import tensorflow as tf
import keras

# %%
#import dataset and annotations into a pandas dataframe
df = pd.read_csv("mitbih_database/101.csv")
annotations = mlbeats.df_from_txt("mitbih_database/101annotations.txt")

#preview of how the dataframe looks
annotations.head()
# Out:
#        Time Sample# Result
# 0  0:00.019       7      +
# 1  0:00.231      83      N
# 2  0:01.100     396      N
# 3  0:01.975     711      N
# 4  0:02.867    1032      N

# %%
#preview of how the plot looks
plt.plot(df["\'sample #\'"], df["\'MLII\'"])

rpeak = []#the list that store the location of peaks
for i in range(len(annotations['Sample#'])):
    x = int(annotations['Sample#'][i])
    plt.scatter(x, df["\'MLII\'"][x], color = 'red')
    rpeak.append(x)
plt.xlim(320000, 330000)
# Out:
# (320000.0, 330000.0)

# %%
#data normalization
mx = np.amax(df["\'MLII\'"])
mn = np.amin(df["\'MLII\'"])

normalized_data = (df["\'MLII\'"] - mn)/(mx - mn)

#data denoising

denoised_data = mlbeats.denoising(normalized_data)

# %%
ecg.ecg(signal=denoised_data, sampling_rate=360, show=True)
# Out:
# ReturnTuple(ts=array([0.00000000e+00, 2.77777778e-03, 5.55555556e-03, ...,
#        1.80554722e+03, 1.80555000e+03, 1.80555278e+03]), filtered=array([ 0.02138187,  0.02083101,  0.02028249, ..., -0.01011175,
#         0.00481907,  0.02373089]), rpeaks=array([    82,    396,    711, ..., 649003, 649371, 649750]), templates_ts=array([-2.00000000e-01, -1.97222222e-01, -1.94444444e-01, -1.91666667e-01,
#        -1.88888889e-01, -1.86111111e-01, -1.83333333e-01, -1.80555556e-01,
#        -1.77777778e-01, -1.75000000e-01, -1.72222222e-01, -1.69444444e-01,
#        -1.66666667e-01, -1.63888889e-01, -1.61111111e-01, -1.58333333e-01,
#        -1.55555556e-01, -1.52777778e-01, -1.50000000e-01, -1.47222222e-01,
#        -1.44444444e-01, -1.41666667e-01, -1.38888889e-01, -1.36111111e-01,
#        -1.33333333e-01, -1.30555556e-01, -1.27777778e-01, -1.25000000e-01,
#        -1.22222222e-01, -1.19444444e-01, -1.16666667e-01, -1.13888889e-01,
#        -1.11111111e-01, -1.08333333e-01, -1.05555556e-01, -1.02777778e-01,
#        -1.00000000e-01, -9.72222222e-02, -9.44444444e-02, -9.16666667e-02,
#        -8.88888889e-02, -8.61111111e-02, -8.33333333e-02, -8.05555556e-02,
#        -7.77777778e-02, -7.50000000e-02, -7.22222222e-02, -6.94444444e-02,
#        -6.66666667e-02, -6.38888889e-02, -6.11111111e-02, -5.83333333e-02,
#        -5.55555556e-02, -5.27777778e-02, -5.00000000e-02, -4.72222222e-02,
#        -4.44444444e-02, -4.16666667e-02, -3.88888889e-02, -3.61111111e-02,
#        -3.33333333e-02, -3.05555556e-02, -2.77777778e-02, -2.50000000e-02,
#        -2.22222222e-02, -1.94444444e-02, -1.66666667e-02, -1.38888889e-02,
#         3.88888889e-01,  3.91666667e-01,  3.94444444e-01,  3.97222222e-01]), templates=array([[0.01627265, 0.01601637, 0.01580003, ..., 0.01795127, 0.01830508,
#         0.0186025 ],
#        [0.02003898, 0.02040532, 0.020633  , ..., 0.0162029 , 0.01644339,
#         0.01671179],
#        [0.02110402, 0.02153093, 0.02185599, ..., 0.01635848, 0.01635261,
#         0.01637753],
#        ...,
#        [0.02243188, 0.02297263, 0.02358812, ..., 0.01605868, 0.01643117,
#         0.01686876],
#        [0.0196555 , 0.0201598 , 0.02057536, ..., 0.01940218, 0.01892136,
#         0.0185026 ],
#        [0.0200984 , 0.02094758, 0.02181915, ..., 0.01703615, 0.01693918,
#         0.01683885]]), heart_rate_ts=array([1.10000000e+00, 1.97500000e+00, 2.86666667e+00, ...,
#        1.80278611e+03, 1.80380833e+03, 1.80486111e+03]), heart_rate=array([68.71701547, 68.2169857 , 66.71562083, ..., 60.01497476,
#        58.7306461 , 57.55994035]))

# %%
#beat extraction
beats, rpeak_beats = ecg.extract_heartbeats(denoised_data, rpeak, sampling_rate=360, before=0.2, after=0.4)

#beat demonstration
plt.figure(figsize= [20, 20])
for i in range(len(beats)):
    x_axis = np.arange(0, len(beats[i]), 1)
    plt.plot(x_axis, beats[i])
    
plt.grid()
plt.show()

# %%
#make beat_annotation data frame
beat_annotation = pd.DataFrame(beats)
label = annotations['Result'].iloc[1:]
beat_annotation.insert(0, "Annotation", label)

# %%
beat_annotation.head()
# Out:
#   Annotation         0         1         2         3         4         5  \
# 0        NaN -0.002659 -0.002167 -0.001560 -0.000890 -0.000365  0.000030
# 1          N -0.010110 -0.010378 -0.010833 -0.010699 -0.009985 -0.008593
# 2          N  0.004333  0.005851  0.007136  0.008189  0.009203  0.009951
# 3          N -0.007260 -0.006220 -0.004818 -0.003411 -0.002025 -0.000819
# 4          N -0.015918 -0.014824 -0.013437 -0.011946 -0.010413 -0.009021
#
#           6         7         8  ...       206       207       208       209  \
# 0  0.000289  0.000445  0.000643  ... -0.013105 -0.013555 -0.013913 -0.014029
# 1 -0.006858 -0.005628 -0.005033  ... -0.007935 -0.007956 -0.007902 -0.007844
# 2  0.010240  0.010219  0.010019  ... -0.005907 -0.006583 -0.007282 -0.007884
# 3  0.000105  0.000767  0.000890  ... -0.010901 -0.011632 -0.012472 -0.013549
# 4 -0.007901 -0.007156 -0.007083  ...  0.004351  0.004169  0.003789  0.003038
#
#         210       211       212       213       214       215
# 0 -0.013699 -0.013183 -0.012812 -0.012695 -0.013090 -0.013731
# 1 -0.007824 -0.007811 -0.007940 -0.008353 -0.008853 -0.009164
# 2 -0.008239 -0.008457 -0.008653 -0.008829 -0.009060 -0.009224
# 3 -0.014727 -0.015781 -0.016664 -0.017239 -0.017534 -0.017692
# 4  0.002033  0.001185  0.000395 -0.000346 -0.000975 -0.001599
#
# [5 rows x 217 columns]

# %%
# Out:
# 1873
